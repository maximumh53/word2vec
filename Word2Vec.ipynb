# %% [markdown]
# # Word2Vec
# Runs Word2Vec on all text files within the same file<br>
# Combine all .txt files into one corpus<br>
# Specify the dimensions of the model<br>
# Creates a word embedding output in both .txt and .bin format<br>
# Credits to Siraj Raval, edited to make more applicable

# %% [markdown]
# ### Imports

# %%
from __future__ import absolute_import, division, print_function
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno -2] Name or
# [nltk_data]     service not known>
# [nltk_data] Error loading stopwords: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>
# False

# %% [markdown]
# ### Read names of .txt files

# %%
text_filenames = sorted(glob.glob('./*.txt'))

# %%
print("Found texts:")
text_filenames
# Out:
# Found texts:
# ['./A-Bayesian-Optimization-Approach-to-Compute-the-Nash-Equilibria-of-Potential-Games-using-Bandit-Feedback.txt',
#  './A-Disaster-Response-System-Based-on-Human-Agent-Collectives.txt',
#  './A-Framework-for-Assessing-the-Performance-of-Pulsar-Search-Pipelines.txt',
#  './A-General-Framework-for-Fair-Regression.txt',
#  './A-Machine-Learning-Approach-to-Risk-Minimisation-in-Electricity-Markets.txt',
#  './A-Machine-Learning-Approach-to-the-Prediction-of-Tidal-Currents.txt',
#  './A-Novel-Approach-to-Forecasting-Financial-Volatility-with-Gaussian-Process-Envelopes.txt',
#  './A-Probabilistic-Approach-to-Nonparametric-Local-Volatility.txt',
#  './A-Proposed-Risk-Modeling-Shift-from-the-Approach-of-SDE-towards-MLC-1.txt',
#  './A-Simulation-of-the-Insurance-Industry-The-Problem-of-Risk-Model-Homogeneity.txt',
#  './A-signature-based-machine-learning-model-for-bipolar-disorder-and-borderline-personality-disorder.txt',
#  './Abate2018_Chapter_ExperimentalBiologicalProtocol.txt',
#  './Abate2018_Chapter_ModellingSmartBuildingsUsingFa.txt',
#  './AdaGeo-Adaptive-Geometric-Learning-for-Optimization-and-Sampling.txt',
#  './AdversarialRobustnessGuaranteesForClassificationWithGaussianProcesses.txt',
#  './Algorithmic-Trading-Stochastic-Control-and-Mutually-Exciting-Processes.txt',
#  './Alternating-Optimisation-and-Quadrature-for-Robust-Control.txt',
#  './An-Accurate-Maximum-Entropy-Method-for-Efficient-Approximations-in-Large-Scale-Machine-Learning.txt',
#  './An-Information-and-Field-Theoretic-Approach-to-the-Grand-Canonical-Ensemble.txt',
#  './An-Introduction-to-Machine-Learning.txt',
#  './An-Iterated-Azéma-Yor-Type-Embedding-for-Finitely-Many-Marginals.txt',
#  './Are-All-Insider-Sales-Created-Equal-.txt',
#  './Asynchronous-Batch-Bayesian-Optimisation-with-Improved-Local-Penalisation.txt',
#  './Automated-Formal-Synthesis-of-Provably-Safe-Digital-Controllers-for-Continuous-Plants.txt',
#  './BCCNet-Bayesian-Classifier-Combination-Neural-Network.txt',
#  './BDLOB-Bayesian-Deep-Convolutional-Neural-Networks-for-Limit-Order-Books.txt',
#  './Battery-Capacity-Estimation-from-Partial-Charging-Data-Using-Gaussian-Process-Regression.txt',
#  './BayesOpt-attack-paper-002.txt',
#  './Bayesian-Heatmaps-Probabilistic-Classification-with-Multiple-Unreliable-Information-Sources.txt',
#  './Bayesian-Inference-of-Log-Determinants.txt',
#  './Bayesian-Nonparametrics-and-Feedback-Linearisation-of-Discretised-Control-Affine-Systems.txt',
#  './Bayesian-Optimisation-of-Gaussian-Processes-for-Identifying-the-Deteriorating-Patient.txt',
#  './Bayesian-Optimization-for-Probabilistic-programs.txt',
#  './Bayesian-Optimization-of-Personalised-Models-for-Patient-Vital-Sign-Monitoring.txt',
#  './BayesianOptimisationoverMultipleContinuousand-CategoricalInputs.txt',
#  './Be-Careful-What-You-Ask-for-Fundraising-Strategies-in-Equity-Crowdfunding.txt',
#  './Behavioural-Attributes-and-Financial-Churn-Prediction.txt',
#  './Bioacoustic-Detection-with-Wavelet-Conditioned-Convolutional-Neural-Networks.txt',
#  './Bounding-Quantiles-of-Wasserstein-Distance-Between-True-and-Empirical-Measure.txt',
#  './Can-Stimulating-Demand-Drive-Cost-Down.-World-War-II-as-a-Natural-Experiment.txt',
#  './Characteristic-Functions-of-Measure-on-Geometric-Rough-Paths.txt',
#  './Closing-the-K-FAC-Generalisation-Gap-Using-Stochastic-Weight-Averaging.txt',
#  './Convergence-of-Heston-to-SVI-Proposed-Extensions-1.txt',
#  './Cost-Sensitive-Detection-with-Variational-Autoencoders-for-Environmental-Acoustic-Sensing.txt',
#  './Customer-Segmentation-of-an-East-African-Microgrid.txt',
#  './Deciphering-Price-Formation-in-the-High-Frequency-Domain-1.txt',
#  './DeepLOB-Deep-Convolutional-Neural-Networks-for-Limit-Order-Books.txt',
#  './Detecting-Intraday-Financial-Market-States-Using-Temporal-Clustering.txt',
#  './Detecting-early-signs-of-depressive-and-manic-episodes-in-patients-with-bipolar-disorder-using-the-signature-based-model.txt',
#  './Deviations-in-Expected-Price-Impact-for-Small-Transaction-Volumes-Under-Fee-Restructuring.txt',
#  './Discretely-sampled-signals-and-the-rough-Hoff-process.txt',
#  './Disentangling-to-Cluster-Gaussian-Mixture-Variational-Ladder.txt',
#  './Distributed-Optimization-for-Energy-Management-in-Building-Networks.txt',
#  './Distribution-of-Gaussian-Process-Arc-Lengths.txt',
#  './Distributionally-Robus-Optimization-Techniques-in-Batch-Bayesian-Optimization.txt',
#  './Do-US-Analysts-Improve-the-Local-Information-Environment-of-Cross-Listed-Stocks.txt',
#  './Dual-Attainment-for-the-Martingale-Transport-Problem.txt',
#  './Earnings-Forecasts-in-Mergers-and-Acquisitions.txt',
#  './Economic-uncertainty-trading-activity-and-commodity-futures-volatility.txt',
#  './Efficiency-Through-Uncertainty-Scalable-Formal-Synthesis-for-Stochastic-Hybrid-Systems.txt',
#  './Emergent-inequality-and-endogenous-dynamics-in-a-simple-bahavioral-macroeconomic-model.txt',
#  './Empirical-Prediction-Intervals-Improve-Energy-Forecasting.txt',
#  './Enhancing-Time-Series-Momentum-Strategies-Using-Deep-Neural-Networks.txt',
#  './Entropic-Determinants-of-Massive-Matrices.txt',
#  './Entropic-Graph-Spectrum-Diego-Granziol.txt',
#  './Entropic-Spectral-Learning-in-Large-Scale-Networks.txt',
#  './Entropic-Trace-Estimates-for-Log-Determinants.txt',
#  './Equity-Crowdfunding-A-New-Phenomena.txt',
#  './European-Option-Pricing-with-Stochastic-Volatility-Models-Under-Parameter.txt',
#  './Extending-Deep-Learning-Models-for-Limit-Order-Books-to-Quantile-Regression.txt',
#  './Extracting-Predictive-Information-from-Heterogeneous-Data-Streams-Using-Gaussian-Processes.txt',
#  './Fast-Information-theoretic-Bayesian-Optimisation.txt',
#  './Forecasting-Energy-Demand-for-Microgrids-over-Multiple-Horizons.txt',
#  './Foreign-Exchange-Markets-with-Last-Look-Mathematics-and-Financial-Economics.txt',
#  './Formal-Control-Synthesis-via-Simulation-Relations-and-Behavioural-Theory-for-Discrete-Time-Descriptor-Systems.txt',
#  './Formal-and-Efficient-Control-Synthesis-for-Continuous-Time-Stochastic-Processes.txt',
#  './GPz-Non-Staionary-Sparse-Gaussian-Processes-for-Heteroscedastic-Uncertainty-Estimation-in-Photometric-Redshifts.txt',
#  './Gaussian-Process-Regression-for-In-Situ-Capacity-Estimation-of-Lithium-Ion-Batteries.txt',
#  './Glasses-Relieving-The-Myopia-of-Bayesian-Optimisation.txt',
#  './Gradient-descent-in-Gaussian-Random-Fields-as-a-Toy-Model-for-High-Dimensional-Optimisation-in-Deep-Learning.txt',
#  './Hedging-Local-Volume-Risk-Using-Forward-Markets-Nordic-Case-Energy-Markets.txt',
#  './Hedging-Non-Tradable-Risks-with-Transaction-Costs-and-Price-Impact.txt',
#  './Herding-in-Equity-Crowdfunding.txt',
#  './High-Dimensional-Time-Series-with-Exogenous-Variables-Using-Generalized-Koopman-Operator-Framework-in-Reproducing-Kernel-Hilbert-Space.txt',
#  './High-speed_detection_of_emergent_market_clustering-1.txt',
#  './How-does-Mini-Batching-Affect-Curvature-Information-for-Second-Order-Deep-Learning-Optimization.txt',
#  './How-well-do-Experience-Curves-Predict-Technological-Progress-A-Method-for-Making-Distributional-Forecasts.txt',
#  './Hyperbolic-development-and-inversion-of-signature.txt',
#  './Identifying-Sources-and-Sinks-in-the-Presence-of-Multiple-Agents-with-Gaussian-Process-Vector-Calculus.txt',
#  './Identifying-Sources-of-Discrimination-Risk-in-the-Life-Cycle-of-Machine-Intelligence-Applications-Under-New-European-Union-Regulations.txt',
#  './Impact-of-Solar-Panels-and-Cooling-Devices-on-Frequency-Control-after-a-Generation-Loss-Incident.txt',
#  './Improved-Stochastic-Trace-Estimation-Using-Mutually-Unbiased-Bases.txt',
#  './Improving-photometric-redshift-estimation-using-GPz-size-information-post-processing-and-improved-photometry.txt',
#  './Indian-Buffet-Neural-Networks-for-Continual-Learning.txt',
#  './Inferring-Agent-Objectives-at-Different-Scales-of-a-Complex-Adaptive-System.txt',
#  './Introducing-the-HFTE-Model-A-MultiSpecies-Predator–Prey-Ecosystem-for-HighFrequency-Quantitative-Financial-Strategies.txt',
#  './Investor-Concentration-Flows-and-Cash-Holdings-Evidence-from-Hedge-Funds.txt',
#  './Kernels-for-Sequentially-Ordered-Data.txt',
#  './Latent-Point-Process-Allocation.txt',
#  './Lazily-Adapted-Constant-Kinky-Inference-for-Nonparametric-Regression-and-Model-Reference-Adaptive-Control.txt',
#  './Learning-Against-Non-Stationary-Agents-with-Opponent-Modelling-and-Deep-Reinforcement-Learning.txt',
#  './Learning-Based-Nonlinear-Model-Predictive-Control.txt',
#  './Learning-Graphs-from-Data-A-Signal-Representation-Perspective.txt',
#  './Learning-Heat-Diffusion-Graphs.txt',
#  './Learning-Laplacian-Matrix-in-Smooth-Graph-Signal-Representations.txt',
#  './Linear-Quadratic-Regulation-of-Polytopic-Time-inhomogeneous-Markov-Jump-Linear-Systems.txt',
#  './Lipschitz-Optimisation-for-Lipschitz-Interpolation.txt',
#  './Localised-Kinky-Inference.txt',
#  './Logically-Constrained-Neural-Fitted-Q-Iteration.txt',
#  './Loss-Calibrated-Approximate-Inference-in-Bayesian-Neural-Networks.txt',
#  './MOrdReD-Memory-based-Ordinal-Regression-Deep-Neural-Networks-for-Time-Series-Forecasting.txt',
#  './Machine-Learning-Techniques-for-Deciphering-Implied-Volatility-Surface-Data-in-a-Hostile-Environment.txt',
#  './Maintenance-of-Smart-Buildings-Using-Fault-Trees.txt',
#  './Market-Dominance-in-Bond-and-CDS-Interdealer-Networks.txt',
#  './Market-Making-with-Minimum-Resting-Times-1.txt',
#  './Market-Making-with-Minimum-Resting-Times.txt',
#  './Measuring-Productivity-Dispersion-a-Parametric-Approach-using-the-Levy-Alpha-Stable-Distribution.txt',
#  './Methods-for-Quantifying-Effects-of-Social-Unrest-Using-Credit-Card-Transaction-Data.txt',
#  './MidGaP-Mixture-Desity-Gaussian-Processes.txt',
#  './Mixture-Density-Conditional-Generative-Adversarial-Network-Models-MD-CGAN.txt',
#  './Modelling-Analysts-Recommendations-via-Bayesian-Machine-Learning.txt',
#  './Multi-Modal-Image-Retrieval-with-Random-Walk-on-Multi-Layer-Graphs.txt',
#  './Multi-Unit-Bilateral-Trade.txt',
#  './Naked-Aggression-Personality-and-Portfolio-Manager-Performance.txt',
#  './No-Regret-Learningand-a-Mechanism-for-Distributed-Multiagent-Planning.txt',
#  './Nonlinear-Set-Membership-Regression-with-Adaptive-Hyper-Parameter-Estimation-for-Online-Learning-and-Control.txt',
#  './Novel-Exploration-Techniques-NETs-for-Malaria-Policy-Interventions.txt',
#  './Online-Optimisation-for-Online-Learning-and-Control-From-No-Regret-to-Generalised-Error-Convergence.txt',
#  './Optimal-Client-Recommendation-for-Market-Makers-in-Illiquid-Financial-Products.txt',
#  './Optimal-Hedge-Tracking-Portfolios-in-a-Limit-Order-Book.txt',
#  './Optimal-Pricing-in-Black-Box-Producer-Consumer-Stackelberg-Games-Using-Revealed-Preference-Feedback.txt',
#  './Optimising-Worlds-to-Evaluate-and-Influence-Reinforcement-Learning-Agents.txt',
#  './Optimization-fast-and-slow-optimally-switching-between-Local-and-Bayesian-Optimization.txt',
#  './Path-Dependent-and-Randomized-Strategies-in-Barberis-Casino-Gambling-Model.txt',
#  './Pathwise-Stochastic-Calculus-with-Local-Times.txt',
#  './Persistence-Paths-and-Signature-Features-in-Topological-Data-Analysis.txt',
#  './Pointwise-Arbitrage-Pricing-Theory-in-Discrete-Time.txt',
#  './Population-based-Global-Optimisation-Methods-for-Learning-Long-term-Dependencies-with-RNNs.txt',
#  './Portfolio-Optimization-for-Cointelated-Pairs-SDEs-vs-Machine-Learning.txt',
#  './Practical-Bayesian-Learning-of-Neural-Networks-via-Adaptive-Subgradient-Optimization-Methods.txt',
#  './Practical-Bayesian-Optimization-for-Variable-Cost-Objectives.txt',
#  './Preconditioning-Kernel-Matrices.txt',
#  './Predicting-sentence-level-polarity-labels-of-financial-news-using-abnormal-stock-returns.txt',
#  './Prediction-of-Tidal-Currents-Using-Bayesian-Machine-Learning.txt',
#  './Pricing-Poseidon-Extreme-Weather-Uncertainty-and-Firm-Return-Dynamics.txt',
#  './Prime-Broker-Exposures-Collateral-and-Resilience-in-Hedge-Fund-Credit-Networks.txt',
#  './Proceedings-of-the-6th-IFAC-Conference-on-Analysis-and-Design-of-Hybrid-Systems.txt',
#  './Provenance-Network-Analytics-An-Approach-to-Data-Analytics-Using-Data-Provenance.txt',
#  './Purchase-Patterns-Socioeconomic-Status-and-Political-Inclination.txt',
#  './Quantum-Algorithms-for-Training-Gaussian-Processes.txt',
#  './Reading-the-Tea-Leaves-A-Neural-Network-Perspective-on-Technical-Trading.txt',
#  './Recurrent-Neural-Filters-Learning-Independent-Bayesian-Filtering-Steps-for-Time-Series-Prediction.txt',
#  './Reinforcement-Learning-in-R.txt',
#  './Reinforcement-Learning-with-Linear-Logic-Guidance.txt',
#  './Risk-Management-with-Weighted-VaR.txt',
#  './Risk-Minimisation-in-Electricity-Markets-Fixed-Price-Unknown-Consumption.txt',
#  './Robust-Data-Based-Model-Predictive-Control-for-Nonlinear-Constrained-Systems.txt',
#  './Robust-Open-Source-Removal-of-Systematics-in-Kepler-Data.txt',
#  './Robust-Pricing-and-Hedging-Under-Trading-Restrictions-and-the-Emergence-of-Local-Martingale-Models.txt',
#  './Robust-Pricing–Hedging-Duality-in-Continuous-Time.txt',
#  './Robust-Trading-of-Implied-Skew.txt',
#  './Rotation-free-Online-Handwritten-Character-Recognition-using-Dyadic-Path-Signature-Features-Hanging-Normalization-and-Deep-Neural-Network.txt',
#  './Safe-Policy-Search-Using-Guassian-Process-Models.txt',
#  './Scalable-Bounding-of-Predictive-Uncertainty-in-Regression-Probems-with-SLAC.txt',
#  './Scenario-Free-Analysis-of-Financial-Stability-with-Interacting-Contagion-Channels.txt',
#  './Semi-separable-Hamiltonian-Monte-Carlo-for-Inference-in-Bayesian-Neural-Networks.txt',
#  './Semi-supervised-Learning-with-Deep-Generative-Models.txt',
#  './Sequential-Sampling-of-Gaussian-Latent-Variable-Models.txt',
#  './Social-Bridges-in-Urban-Purchase-Behaviour.txt',
#  './Solving-Strong-Substitutes-Product-Mix-Auctions.txt',
#  './Speculative-Trading-of-Electricity-Contracts-in-Interconnected-Locations.txt',
#  './Spoofing-and-Price-Manipulation-in-Order-Driven-Markets.txt',
#  './Stochastic-Volatility-for-Utility-Maximizers-A-Martingale-Approach.txt',
#  './Stochy-automatic-verification-and-synthesis-of-stochastic-processes.txt',
#  './String-and-Membrane-Gaussian-Processes.txt',
#  './Super-resolution-of-Time-series-Labels-for-Bootstrapped-Event-Detection.txt',
#  './Symbolic-Abstractions-of-Networked-Control-Systems.txt',
#  './System-for-Identifying-Monitoring-and-Ranking-Incidents-from-Social-Media.txt',
#  './Technical_uncertainty_in_real_options_with_learning_final.txt',
#  './The-Atalanta-eﬀect-How-high-powered-compensation-reduces-risk-taking.txt',
#  './The-Deep-Learning-Limit-Are-Negative-Neural-Network-Eigenvalues-Just-Noise.txt',
#  './The-Effects-of-the-Volcker-Rule-on-Corporate-Bond-Trading-Evidence-from-the-Underwriting-Exemption.txt',
#  './The-Fundamental-Theorem-of-Derivatives-Trading-Exposition-Extensions-and-Experiments.txt',
#  './The-Future-of-Employment-How-Susceptible-are-Jobs-to-Computerisation.txt',
#  './The-Hairy-Ball-Problem-is-PPAD-Complete.txt',
#  './The-Incentives-of-Hedge-Fund-Fees-and-High-Water-Marks.txt',
#  './The-Maximum-Maximum-of-Martingales-with-given-Marginals.txt',
#  './The-Numeraire-Property-and-Long-Term-Growth-Optimality-for-Drawdown-Constrained-Investments.txt',
#  './The-Rippling-Effect-of-Social-Influence-via-Phone-Communication-Network.txt',
#  './The-Robust-Pricing-Hedging-Duality-for-American-Options-in-Discrete-Time-Financial-Markets.txt',
#  './The-Root-Solution-to-the-Multi-Marginal-Embedding-Problem-An-Optimal-Stopping-and-Time-Reversal-Approach.txt',
#  './The-Signature-of-a-Rough-Path-Uniqueness.txt',
#  './The-Statistical-Significance-of-Multivariate-Hawkes-Processes-Fitted-to-Limit-Order-Book-Data.txt',
#  './Thresholded-ConvNet-Ensembles-Neural-Networks-for-Technical-Forecasting.txt',
#  './Time–Consistent-Investment-Under-Model-Uncertainty-The-Robust-Forward-Criteria.txt',
#  './Tropical-Abstractions-of-Max-Plus-Linear-Systems.txt',
#  './Two-explicit-Skorokhod-embeddings-for-simple-symmetric-random-walk.txt',
#  './Ultra-Fast-Activity-and-Intraday-Market-Quality-1.txt',
#  './Ultra-Fast-Activity-and-Intraday-Market-Quality.txt',
#  './Using-real-time-cluster.txt',
#  './Volatility-is-Log-Normal-but-not-for-the-reason-you-think.txt',
#  './WiSE-ALE-Wide-Sample-Estimator-for-Approximate-Latent-Embedding.txt',
#  './hedge-fund-performance-are-stylised-facts.txt',
#  './model100.txt',
#  './super-multiplicativity.txt']

# %% [markdown]
# ### combine .txt files into a large corpus

# %%
corpus_raw = u""
for text_filename in text_filenames:
    print("Reading '{0}'...".format(text_filename))
    with codecs.open(text_filename, "r", "utf-8") as text_file:
        corpus_raw += text_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading './A-Bayesian-Optimization-Approach-to-Compute-the-Nash-Equilibria-of-Potential-Games-using-Bandit-Feedback.txt'...
# Corpus is now 43939 characters long
#
# Reading './A-Disaster-Response-System-Based-on-Human-Agent-Collectives.txt'...
# Corpus is now 196949 characters long
#
# Reading './A-Framework-for-Assessing-the-Performance-of-Pulsar-Search-Pipelines.txt'...
# Corpus is now 283053 characters long
#
# Reading './A-General-Framework-for-Fair-Regression.txt'...
# Corpus is now 329803 characters long
#
# Reading './A-Machine-Learning-Approach-to-Risk-Minimisation-in-Electricity-Markets.txt'...
# Corpus is now 381392 characters long
#
# Reading './A-Machine-Learning-Approach-to-the-Prediction-of-Tidal-Currents.txt'...
# Corpus is now 416454 characters long
#
# Reading './A-Novel-Approach-to-Forecasting-Financial-Volatility-with-Gaussian-Process-Envelopes.txt'...
# Corpus is now 455924 characters long
#
# Reading './A-Probabilistic-Approach-to-Nonparametric-Local-Volatility.txt'...
# Corpus is now 555150 characters long
#
# Reading './A-Proposed-Risk-Modeling-Shift-from-the-Approach-of-SDE-towards-MLC-1.txt'...
# Corpus is now 682257 characters long
#
# Reading './A-Simulation-of-the-Insurance-Industry-The-Problem-of-Risk-Model-Homogeneity.txt'...
# Corpus is now 782402 characters long
#
# Reading './A-signature-based-machine-learning-model-for-bipolar-disorder-and-borderline-personality-disorder.txt'...
# Corpus is now 803835 characters long
#
# Reading './Abate2018_Chapter_ExperimentalBiologicalProtocol.txt'...
# Corpus is now 849142 characters long
#
# Reading './Abate2018_Chapter_ModellingSmartBuildingsUsingFa.txt'...
# Corpus is now 895684 characters long
#
# Reading './AdaGeo-Adaptive-Geometric-Learning-for-Optimization-and-Sampling.txt'...
# Corpus is now 914666 characters long
#
# Reading './AdversarialRobustnessGuaranteesForClassificationWithGaussianProcesses.txt'...
# Corpus is now 958055 characters long
#
# Reading './Algorithmic-Trading-Stochastic-Control-and-Mutually-Exciting-Processes.txt'...
# Corpus is now 1052826 characters long
#
# Reading './Alternating-Optimisation-and-Quadrature-for-Robust-Control.txt'...
# Corpus is now 1095724 characters long
#
# Reading './An-Accurate-Maximum-Entropy-Method-for-Efficient-Approximations-in-Large-Scale-Machine-Learning.txt'...
# Corpus is now 1145755 characters long
#
# Reading './An-Information-and-Field-Theoretic-Approach-to-the-Grand-Canonical-Ensemble.txt'...
# Corpus is now 1184646 characters long
#
# Reading './An-Introduction-to-Machine-Learning.txt'...
# Corpus is now 1225695 characters long
#
# Reading './An-Iterated-Azéma-Yor-Type-Embedding-for-Finitely-Many-Marginals.txt'...
# Corpus is now 1291859 characters long
#
# Reading './Are-All-Insider-Sales-Created-Equal-.txt'...
# Corpus is now 1410768 characters long
#
# Reading './Asynchronous-Batch-Bayesian-Optimisation-with-Improved-Local-Penalisation.txt'...
# Corpus is now 1467775 characters long
#
# Reading './Automated-Formal-Synthesis-of-Provably-Safe-Digital-Controllers-for-Continuous-Plants.txt'...
# Corpus is now 1536434 characters long
#
# Reading './BCCNet-Bayesian-Classifier-Combination-Neural-Network.txt'...
# Corpus is now 1552740 characters long
#
# Reading './BDLOB-Bayesian-Deep-Convolutional-Neural-Networks-for-Limit-Order-Books.txt'...
# Corpus is now 1572510 characters long
#
# Reading './Battery-Capacity-Estimation-from-Partial-Charging-Data-Using-Gaussian-Process-Regression.txt'...
# Corpus is now 1612542 characters long
#
# Reading './BayesOpt-attack-paper-002.txt'...
# Corpus is now 1668872 characters long
#
# Reading './Bayesian-Heatmaps-Probabilistic-Classification-with-Multiple-Unreliable-Information-Sources.txt'...
# Corpus is now 1714106 characters long
#
# Reading './Bayesian-Inference-of-Log-Determinants.txt'...
# Corpus is now 1755614 characters long
#
# Reading './Bayesian-Nonparametrics-and-Feedback-Linearisation-of-Discretised-Control-Affine-Systems.txt'...
# Corpus is now 1799260 characters long
#
# Reading './Bayesian-Optimisation-of-Gaussian-Processes-for-Identifying-the-Deteriorating-Patient.txt'...
# Corpus is now 1819450 characters long
#
# Reading './Bayesian-Optimization-for-Probabilistic-programs.txt'...
# Corpus is now 1855980 characters long
#
# Reading './Bayesian-Optimization-of-Personalised-Models-for-Patient-Vital-Sign-Monitoring.txt'...
# Corpus is now 1915453 characters long
#
# Reading './BayesianOptimisationoverMultipleContinuousand-CategoricalInputs.txt'...
# Corpus is now 1959311 characters long
#
# Reading './Be-Careful-What-You-Ask-for-Fundraising-Strategies-in-Equity-Crowdfunding.txt'...
# Corpus is now 2116567 characters long
#
# Reading './Behavioural-Attributes-and-Financial-Churn-Prediction.txt'...
# Corpus is now 2188482 characters long
#
# Reading './Bioacoustic-Detection-with-Wavelet-Conditioned-Convolutional-Neural-Networks.txt'...
# Corpus is now 2242687 characters long
#
# Reading './Bounding-Quantiles-of-Wasserstein-Distance-Between-True-and-Empirical-Measure.txt'...
# Corpus is now 2286625 characters long
#
# Reading './Can-Stimulating-Demand-Drive-Cost-Down.-World-War-II-as-a-Natural-Experiment.txt'...
# Corpus is now 2441688 characters long
#
# Reading './Characteristic-Functions-of-Measure-on-Geometric-Rough-Paths.txt'...
# Corpus is now 2524907 characters long
#
# Reading './Closing-the-K-FAC-Generalisation-Gap-Using-Stochastic-Weight-Averaging.txt'...
# Corpus is now 2540143 characters long
#
# Reading './Convergence-of-Heston-to-SVI-Proposed-Extensions-1.txt'...
# Corpus is now 2589923 characters long
#
# Reading './Cost-Sensitive-Detection-with-Variational-Autoencoders-for-Environmental-Acoustic-Sensing.txt'...
# Corpus is now 2610418 characters long
#
# Reading './Customer-Segmentation-of-an-East-African-Microgrid.txt'...
# Corpus is now 2639526 characters long
#
# Reading './Deciphering-Price-Formation-in-the-High-Frequency-Domain-1.txt'...
# Corpus is now 2753136 characters long
#
# Reading './DeepLOB-Deep-Convolutional-Neural-Networks-for-Limit-Order-Books.txt'...
# Corpus is now 2823399 characters long
#
# Reading './Detecting-Intraday-Financial-Market-States-Using-Temporal-Clustering.txt'...
# Corpus is now 2904176 characters long
#
# Reading './Detecting-early-signs-of-depressive-and-manic-episodes-in-patients-with-bipolar-disorder-using-the-signature-based-model.txt'...
# Corpus is now 2947479 characters long
#
# Reading './Deviations-in-Expected-Price-Impact-for-Small-Transaction-Volumes-Under-Fee-Restructuring.txt'...
# Corpus is now 2998173 characters long
#
# Reading './Discretely-sampled-signals-and-the-rough-Hoff-process.txt'...
# Corpus is now 3049843 characters long
#
# Reading './Disentangling-to-Cluster-Gaussian-Mixture-Variational-Ladder.txt'...
# Corpus is now 3066989 characters long
#
# Reading './Distributed-Optimization-for-Energy-Management-in-Building-Networks.txt'...
# Corpus is now 3096253 characters long
#
# Reading './Distribution-of-Gaussian-Process-Arc-Lengths.txt'...
# Corpus is now 3128413 characters long
#
# Reading './Distributionally-Robus-Optimization-Techniques-in-Batch-Bayesian-Optimization.txt'...
# Corpus is now 3164473 characters long
#
# Reading './Do-US-Analysts-Improve-the-Local-Information-Environment-of-Cross-Listed-Stocks.txt'...
# Corpus is now 3304419 characters long
#
# Reading './Dual-Attainment-for-the-Martingale-Transport-Problem.txt'...
# Corpus is now 3342688 characters long
#
# Reading './Earnings-Forecasts-in-Mergers-and-Acquisitions.txt'...
# Corpus is now 3461053 characters long
#
# Reading './Economic-uncertainty-trading-activity-and-commodity-futures-volatility.txt'...
# Corpus is now 3555408 characters long
#
# Reading './Efficiency-Through-Uncertainty-Scalable-Formal-Synthesis-for-Stochastic-Hybrid-Systems.txt'...
# Corpus is now 3620445 characters long
#
# Reading './Emergent-inequality-and-endogenous-dynamics-in-a-simple-bahavioral-macroeconomic-model.txt'...
# Corpus is now 3675391 characters long
#
# Reading './Empirical-Prediction-Intervals-Improve-Energy-Forecasting.txt'...
# Corpus is now 3719678 characters long
#
# Reading './Enhancing-Time-Series-Momentum-Strategies-Using-Deep-Neural-Networks.txt'...
# Corpus is now 3788291 characters long
#
# Reading './Entropic-Determinants-of-Massive-Matrices.txt'...
# Corpus is now 3817527 characters long
#
# Reading './Entropic-Graph-Spectrum-Diego-Granziol.txt'...
# Corpus is now 3831660 characters long
#
# Reading './Entropic-Spectral-Learning-in-Large-Scale-Networks.txt'...
# Corpus is now 3875462 characters long
#
# Reading './Entropic-Trace-Estimates-for-Log-Determinants.txt'...
# Corpus is now 3914578 characters long
#
# Reading './Equity-Crowdfunding-A-New-Phenomena.txt'...
# Corpus is now 3967170 characters long
#
# Reading './European-Option-Pricing-with-Stochastic-Volatility-Models-Under-Parameter.txt'...
# Corpus is now 4077696 characters long
#
# Reading './Extending-Deep-Learning-Models-for-Limit-Order-Books-to-Quantile-Regression.txt'...
# Corpus is now 4098966 characters long
#
# Reading './Extracting-Predictive-Information-from-Heterogeneous-Data-Streams-Using-Gaussian-Processes.txt'...
# Corpus is now 4135548 characters long
#
# Reading './Fast-Information-theoretic-Bayesian-Optimisation.txt'...
# Corpus is now 4151866 characters long
#
# Reading './Forecasting-Energy-Demand-for-Microgrids-over-Multiple-Horizons.txt'...
# Corpus is now 4181507 characters long
#
# Reading './Foreign-Exchange-Markets-with-Last-Look-Mathematics-and-Financial-Economics.txt'...
# Corpus is now 4259981 characters long
#
# Reading './Formal-Control-Synthesis-via-Simulation-Relations-and-Behavioural-Theory-for-Discrete-Time-Descriptor-Systems.txt'...
# Corpus is now 4297572 characters long
#
# Reading './Formal-and-Efficient-Control-Synthesis-for-Continuous-Time-Stochastic-Processes.txt'...
# Corpus is now 4394430 characters long
#
# Reading './GPz-Non-Staionary-Sparse-Gaussian-Processes-for-Heteroscedastic-Uncertainty-Estimation-in-Photometric-Redshifts.txt'...
# Corpus is now 4458479 characters long
#
# Reading './Gaussian-Process-Regression-for-In-Situ-Capacity-Estimation-of-Lithium-Ion-Batteries.txt'...
# Corpus is now 4524328 characters long
#
# Reading './Glasses-Relieving-The-Myopia-of-Bayesian-Optimisation.txt'...
# Corpus is now 4562303 characters long
#
# Reading './Gradient-descent-in-Gaussian-Random-Fields-as-a-Toy-Model-for-High-Dimensional-Optimisation-in-Deep-Learning.txt'...
# Corpus is now 4598174 characters long
#
# Reading './Hedging-Local-Volume-Risk-Using-Forward-Markets-Nordic-Case-Energy-Markets.txt'...
# Corpus is now 4681290 characters long
#
# Reading './Hedging-Non-Tradable-Risks-with-Transaction-Costs-and-Price-Impact.txt'...
# Corpus is now 4761290 characters long
#
# Reading './Herding-in-Equity-Crowdfunding.txt'...
# Corpus is now 4903903 characters long
#
# Reading './High-Dimensional-Time-Series-with-Exogenous-Variables-Using-Generalized-Koopman-Operator-Framework-in-Reproducing-Kernel-Hilbert-Space.txt'...
# Corpus is now 5001849 characters long
#
# Reading './High-speed_detection_of_emergent_market_clustering-1.txt'...
# Corpus is now 5061232 characters long
#
# Reading './How-does-Mini-Batching-Affect-Curvature-Information-for-Second-Order-Deep-Learning-Optimization.txt'...
# Corpus is now 5075807 characters long
#
# Reading './How-well-do-Experience-Curves-Predict-Technological-Progress-A-Method-for-Making-Distributional-Forecasts.txt'...
# Corpus is now 5154267 characters long
#
# Reading './Hyperbolic-development-and-inversion-of-signature.txt'...
# Corpus is now 5194548 characters long
#
# Reading './Identifying-Sources-and-Sinks-in-the-Presence-of-Multiple-Agents-with-Gaussian-Process-Vector-Calculus.txt'...
# Corpus is now 5240684 characters long
#
# Reading './Identifying-Sources-of-Discrimination-Risk-in-the-Life-Cycle-of-Machine-Intelligence-Applications-Under-New-European-Union-Regulations.txt'...
# Corpus is now 5283385 characters long
#
# Reading './Impact-of-Solar-Panels-and-Cooling-Devices-on-Frequency-Control-after-a-Generation-Loss-Incident.txt'...
# Corpus is now 5317211 characters long
#
# Reading './Improved-Stochastic-Trace-Estimation-Using-Mutually-Unbiased-Bases.txt'...
# Corpus is now 5350324 characters long
#
# Reading './Improving-photometric-redshift-estimation-using-GPz-size-information-post-processing-and-improved-photometry.txt'...
# Corpus is now 5414086 characters long
#
# Reading './Indian-Buffet-Neural-Networks-for-Continual-Learning.txt'...
# Corpus is now 5459204 characters long
#
# Reading './Inferring-Agent-Objectives-at-Different-Scales-of-a-Complex-Adaptive-System.txt'...
# Corpus is now 5477655 characters long
#
# Reading './Introducing-the-HFTE-Model-A-MultiSpecies-Predator–Prey-Ecosystem-for-HighFrequency-Quantitative-Financial-Strategies.txt'...
# Corpus is now 5554934 characters long
#
# Reading './Investor-Concentration-Flows-and-Cash-Holdings-Evidence-from-Hedge-Funds.txt'...
# Corpus is now 5678769 characters long
#
# Reading './Kernels-for-Sequentially-Ordered-Data.txt'...
# Corpus is now 5774832 characters long
#
# Reading './Latent-Point-Process-Allocation.txt'...
# Corpus is now 5811997 characters long
#
# Reading './Lazily-Adapted-Constant-Kinky-Inference-for-Nonparametric-Regression-and-Model-Reference-Adaptive-Control.txt'...
# Corpus is now 5940736 characters long
#
# Reading './Learning-Against-Non-Stationary-Agents-with-Opponent-Modelling-and-Deep-Reinforcement-Learning.txt'...
# Corpus is now 5968579 characters long
#
# Reading './Learning-Based-Nonlinear-Model-Predictive-Control.txt'...
# Corpus is now 6014416 characters long
#
# Reading './Learning-Graphs-from-Data-A-Signal-Representation-Perspective.txt'...
# Corpus is now 6127965 characters long
#
# Reading './Learning-Heat-Diffusion-Graphs.txt'...
# Corpus is now 6209034 characters long
#
# Reading './Learning-Laplacian-Matrix-in-Smooth-Graph-Signal-Representations.txt'...
# Corpus is now 6292817 characters long
#
# Reading './Linear-Quadratic-Regulation-of-Polytopic-Time-inhomogeneous-Markov-Jump-Linear-Systems.txt'...
# Corpus is now 6329706 characters long
#
# Reading './Lipschitz-Optimisation-for-Lipschitz-Interpolation.txt'...
# Corpus is now 6364814 characters long
#
# Reading './Localised-Kinky-Inference.txt'...
# Corpus is now 6406850 characters long
#
# Reading './Logically-Constrained-Neural-Fitted-Q-Iteration.txt'...
# Corpus is now 6423949 characters long
#
# Reading './Loss-Calibrated-Approximate-Inference-in-Bayesian-Neural-Networks.txt'...
# Corpus is now 6476774 characters long
#
# Reading './MOrdReD-Memory-based-Ordinal-Regression-Deep-Neural-Networks-for-Time-Series-Forecasting.txt'...
# Corpus is now 6564993 characters long
#
# Reading './Machine-Learning-Techniques-for-Deciphering-Implied-Volatility-Surface-Data-in-a-Hostile-Environment.txt'...
# Corpus is now 6679841 characters long
#
# Reading './Maintenance-of-Smart-Buildings-Using-Fault-Trees.txt'...
# Corpus is now 6753371 characters long
#
# Reading './Market-Dominance-in-Bond-and-CDS-Interdealer-Networks.txt'...
# Corpus is now 6823490 characters long
#
# Reading './Market-Making-with-Minimum-Resting-Times-1.txt'...
# Corpus is now 6893413 characters long
#
# Reading './Market-Making-with-Minimum-Resting-Times.txt'...
# Corpus is now 6961520 characters long
#
# Reading './Measuring-Productivity-Dispersion-a-Parametric-Approach-using-the-Levy-Alpha-Stable-Distribution.txt'...
# Corpus is now 7105805 characters long
#
# Reading './Methods-for-Quantifying-Effects-of-Social-Unrest-Using-Credit-Card-Transaction-Data.txt'...
# Corpus is now 7175587 characters long
#
# Reading './MidGaP-Mixture-Desity-Gaussian-Processes.txt'...
# Corpus is now 7187384 characters long
#
# Reading './Mixture-Density-Conditional-Generative-Adversarial-Network-Models-MD-CGAN.txt'...
# Corpus is now 7204294 characters long
#
# Reading './Modelling-Analysts-Recommendations-via-Bayesian-Machine-Learning.txt'...
# Corpus is now 7287352 characters long
#
# Reading './Multi-Modal-Image-Retrieval-with-Random-Walk-on-Multi-Layer-Graphs.txt'...
# Corpus is now 7318060 characters long
#
# Reading './Multi-Unit-Bilateral-Trade.txt'...
# Corpus is now 7401422 characters long
#
# Reading './Naked-Aggression-Personality-and-Portfolio-Manager-Performance.txt'...
# Corpus is now 7459149 characters long
#
# Reading './No-Regret-Learningand-a-Mechanism-for-Distributed-Multiagent-Planning.txt'...
# Corpus is now 7507359 characters long
#
# Reading './Nonlinear-Set-Membership-Regression-with-Adaptive-Hyper-Parameter-Estimation-for-Online-Learning-and-Control.txt'...
# Corpus is now 7540718 characters long
#
# Reading './Novel-Exploration-Techniques-NETs-for-Malaria-Policy-Interventions.txt'...
# Corpus is now 7569651 characters long
#
# Reading './Online-Optimisation-for-Online-Learning-and-Control-From-No-Regret-to-Generalised-Error-Convergence.txt'...
# Corpus is now 7604840 characters long
#
# Reading './Optimal-Client-Recommendation-for-Market-Makers-in-Illiquid-Financial-Products.txt'...
# Corpus is now 7637576 characters long
#
# Reading './Optimal-Hedge-Tracking-Portfolios-in-a-Limit-Order-Book.txt'...
# Corpus is now 7714413 characters long
#
# Reading './Optimal-Pricing-in-Black-Box-Producer-Consumer-Stackelberg-Games-Using-Revealed-Preference-Feedback.txt'...
# Corpus is now 7740277 characters long
#
# Reading './Optimising-Worlds-to-Evaluate-and-Influence-Reinforcement-Learning-Agents.txt'...
# Corpus is now 7752446 characters long
#
# Reading './Optimization-fast-and-slow-optimally-switching-between-Local-and-Bayesian-Optimization.txt'...
# Corpus is now 7793197 characters long
#
# Reading './Path-Dependent-and-Randomized-Strategies-in-Barberis-Casino-Gambling-Model.txt'...
# Corpus is now 7824296 characters long
#
# Reading './Pathwise-Stochastic-Calculus-with-Local-Times.txt'...
# Corpus is now 7918606 characters long
#
# Reading './Persistence-Paths-and-Signature-Features-in-Topological-Data-Analysis.txt'...
# Corpus is now 7972566 characters long
#
# Reading './Pointwise-Arbitrage-Pricing-Theory-in-Discrete-Time.txt'...
# Corpus is now 8058713 characters long
#
# Reading './Population-based-Global-Optimisation-Methods-for-Learning-Long-term-Dependencies-with-RNNs.txt'...
# Corpus is now 8080398 characters long
#
# Reading './Portfolio-Optimization-for-Cointelated-Pairs-SDEs-vs-Machine-Learning.txt'...
# Corpus is now 8142983 characters long
#
# Reading './Practical-Bayesian-Learning-of-Neural-Networks-via-Adaptive-Subgradient-Optimization-Methods.txt'...
# Corpus is now 8184282 characters long
#
# Reading './Practical-Bayesian-Optimization-for-Variable-Cost-Objectives.txt'...
# Corpus is now 8212831 characters long
#
# Reading './Preconditioning-Kernel-Matrices.txt'...
# Corpus is now 8269645 characters long
#
# Reading './Predicting-sentence-level-polarity-labels-of-financial-news-using-abnormal-stock-returns.txt'...
# Corpus is now 8344405 characters long
#
# Reading './Prediction-of-Tidal-Currents-Using-Bayesian-Machine-Learning.txt'...
# Corpus is now 8396284 characters long
#
# Reading './Pricing-Poseidon-Extreme-Weather-Uncertainty-and-Firm-Return-Dynamics.txt'...
# Corpus is now 8521802 characters long
#
# Reading './Prime-Broker-Exposures-Collateral-and-Resilience-in-Hedge-Fund-Credit-Networks.txt'...
# Corpus is now 8523892 characters long
#
# Reading './Proceedings-of-the-6th-IFAC-Conference-on-Analysis-and-Design-of-Hybrid-Systems.txt'...
# Corpus is now 8557803 characters long
#
# Reading './Provenance-Network-Analytics-An-Approach-to-Data-Analytics-Using-Data-Provenance.txt'...
# Corpus is now 8643699 characters long
#
# Reading './Purchase-Patterns-Socioeconomic-Status-and-Political-Inclination.txt'...
# Corpus is now 8662029 characters long
#
# Reading './Quantum-Algorithms-for-Training-Gaussian-Processes.txt'...
# Corpus is now 8689800 characters long
#
# Reading './Reading-the-Tea-Leaves-A-Neural-Network-Perspective-on-Technical-Trading.txt'...
# Corpus is now 8725332 characters long
#
# Reading './Recurrent-Neural-Filters-Learning-Independent-Bayesian-Filtering-Steps-for-Time-Series-Prediction.txt'...
# Corpus is now 8782035 characters long
#
# Reading './Reinforcement-Learning-in-R.txt'...
# Corpus is now 8807916 characters long
#
# Reading './Reinforcement-Learning-with-Linear-Logic-Guidance.txt'...
# Corpus is now 8950877 characters long
#
# Reading './Risk-Management-with-Weighted-VaR.txt'...
# Corpus is now 9042783 characters long
#
# Reading './Risk-Minimisation-in-Electricity-Markets-Fixed-Price-Unknown-Consumption.txt'...
# Corpus is now 9127587 characters long
#
# Reading './Robust-Data-Based-Model-Predictive-Control-for-Nonlinear-Constrained-Systems.txt'...
# Corpus is now 9159587 characters long
#
# Reading './Robust-Open-Source-Removal-of-Systematics-in-Kepler-Data.txt'...
# Corpus is now 9219563 characters long
#
# Reading './Robust-Pricing-and-Hedging-Under-Trading-Restrictions-and-the-Emergence-of-Local-Martingale-Models.txt'...
# Corpus is now 9300575 characters long
#
# Reading './Robust-Pricing–Hedging-Duality-in-Continuous-Time.txt'...
# Corpus is now 9420305 characters long
#
# Reading './Robust-Trading-of-Implied-Skew.txt'...
# Corpus is now 9514249 characters long
#
# Reading './Rotation-free-Online-Handwritten-Character-Recognition-using-Dyadic-Path-Signature-Features-Hanging-Normalization-and-Deep-Neural-Network.txt'...
# Corpus is now 9545195 characters long
#
# Reading './Safe-Policy-Search-Using-Guassian-Process-Models.txt'...
# Corpus is now 9593145 characters long
#
# Reading './Scalable-Bounding-of-Predictive-Uncertainty-in-Regression-Probems-with-SLAC.txt'...
# Corpus is now 9611355 characters long
#
# Reading './Scenario-Free-Analysis-of-Financial-Stability-with-Interacting-Contagion-Channels.txt'...
# Corpus is now 9738685 characters long
#
# Reading './Semi-separable-Hamiltonian-Monte-Carlo-for-Inference-in-Bayesian-Neural-Networks.txt'...
# Corpus is now 9757779 characters long
#
# Reading './Semi-supervised-Learning-with-Deep-Generative-Models.txt'...
# Corpus is now 9774289 characters long
#
# Reading './Sequential-Sampling-of-Gaussian-Latent-Variable-Models.txt'...
# Corpus is now 9814211 characters long
#
# Reading './Social-Bridges-in-Urban-Purchase-Behaviour.txt'...
# Corpus is now 9920684 characters long
#
# Reading './Solving-Strong-Substitutes-Product-Mix-Auctions.txt'...
# Corpus is now 10045720 characters long
#
# Reading './Speculative-Trading-of-Electricity-Contracts-in-Interconnected-Locations.txt'...
# Corpus is now 10102296 characters long
#
# Reading './Spoofing-and-Price-Manipulation-in-Order-Driven-Markets.txt'...
# Corpus is now 10175712 characters long
#
# Reading './Stochastic-Volatility-for-Utility-Maximizers-A-Martingale-Approach.txt'...
# Corpus is now 10268598 characters long
#
# Reading './Stochy-automatic-verification-and-synthesis-of-stochastic-processes.txt'...
# Corpus is now 10279310 characters long
#
# Reading './String-and-Membrane-Gaussian-Processes.txt'...
# Corpus is now 10488849 characters long
#
# Reading './Super-resolution-of-Time-series-Labels-for-Bootstrapped-Event-Detection.txt'...
# Corpus is now 10509438 characters long
#
# Reading './Symbolic-Abstractions-of-Networked-Control-Systems.txt'...
# Corpus is now 10587113 characters long
#
# Reading './System-for-Identifying-Monitoring-and-Ranking-Incidents-from-Social-Media.txt'...
# Corpus is now 10638635 characters long
#
# Reading './Technical_uncertainty_in_real_options_with_learning_final.txt'...
# Corpus is now 10691554 characters long
#
# Reading './The-Atalanta-eﬀect-How-high-powered-compensation-reduces-risk-taking.txt'...
# Corpus is now 10913859 characters long
#
# Reading './The-Deep-Learning-Limit-Are-Negative-Neural-Network-Eigenvalues-Just-Noise.txt'...
# Corpus is now 10937364 characters long
#
# Reading './The-Effects-of-the-Volcker-Rule-on-Corporate-Bond-Trading-Evidence-from-the-Underwriting-Exemption.txt'...
# Corpus is now 11049692 characters long
#
# Reading './The-Fundamental-Theorem-of-Derivatives-Trading-Exposition-Extensions-and-Experiments.txt'...
# Corpus is now 11122854 characters long
#
# Reading './The-Future-of-Employment-How-Susceptible-are-Jobs-to-Computerisation.txt'...
# Corpus is now 11298611 characters long
#
# Reading './The-Hairy-Ball-Problem-is-PPAD-Complete.txt'...
# Corpus is now 11428613 characters long
#
# Reading './The-Incentives-of-Hedge-Fund-Fees-and-High-Water-Marks.txt'...
# Corpus is now 11485116 characters long
#
# Reading './The-Maximum-Maximum-of-Martingales-with-given-Marginals.txt'...
# Corpus is now 11576737 characters long
#
# Reading './The-Numeraire-Property-and-Long-Term-Growth-Optimality-for-Drawdown-Constrained-Investments.txt'...
# Corpus is now 11658675 characters long
#
# Reading './The-Rippling-Effect-of-Social-Influence-via-Phone-Communication-Network.txt'...
# Corpus is now 11684969 characters long
#
# Reading './The-Robust-Pricing-Hedging-Duality-for-American-Options-in-Discrete-Time-Financial-Markets.txt'...
# Corpus is now 11782093 characters long
#
# Reading './The-Root-Solution-to-the-Multi-Marginal-Embedding-Problem-An-Optimal-Stopping-and-Time-Reversal-Approach.txt'...
# Corpus is now 11881241 characters long
#
# Reading './The-Signature-of-a-Rough-Path-Uniqueness.txt'...
# Corpus is now 11918921 characters long
#
# Reading './The-Statistical-Significance-of-Multivariate-Hawkes-Processes-Fitted-to-Limit-Order-Book-Data.txt'...
# Corpus is now 11965934 characters long
#
# Reading './Thresholded-ConvNet-Ensembles-Neural-Networks-for-Technical-Forecasting.txt'...
# Corpus is now 12009125 characters long
#
# Reading './Time–Consistent-Investment-Under-Model-Uncertainty-The-Robust-Forward-Criteria.txt'...
# Corpus is now 12117135 characters long
#
# Reading './Tropical-Abstractions-of-Max-Plus-Linear-Systems.txt'...
# Corpus is now 12156041 characters long
#
# Reading './Two-explicit-Skorokhod-embeddings-for-simple-symmetric-random-walk.txt'...
# Corpus is now 12195821 characters long
#
# Reading './Ultra-Fast-Activity-and-Intraday-Market-Quality-1.txt'...
# Corpus is now 12333468 characters long
#
# Reading './Ultra-Fast-Activity-and-Intraday-Market-Quality.txt'...
# Corpus is now 12475483 characters long
#
# Reading './Using-real-time-cluster.txt'...
# Corpus is now 12530117 characters long
#
# Reading './Volatility-is-Log-Normal-but-not-for-the-reason-you-think.txt'...
# Corpus is now 12579414 characters long
#
# Reading './WiSE-ALE-Wide-Sample-Estimator-for-Approximate-Latent-Embedding.txt'...
# Corpus is now 12626874 characters long
#
# Reading './hedge-fund-performance-are-stylised-facts.txt'...
# Corpus is now 12761043 characters long
#
# Reading './model100.txt'...
# Corpus is now 40566310 characters long
#
# Reading './super-multiplicativity.txt'...
# Corpus is now 40577824 characters long

# %% [markdown]
# ### Preprocessing of corpus (tokenizing and removing stopwords)

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Applications of game theory include a wide range of economic phenomena such as
# auctions [17], oligopolies, social network formation [15], behavioral economics and political economics; just to name a few.
# ['Applications', 'of', 'game', 'theory', 'include', 'a', 'wide', 'range', 'of', 'economic', 'phenomena', 'such', 'as', 'auctions', 'oligopolies', 'social', 'network', 'formation', 'behavioral', 'economics', 'and', 'political', 'economics', 'just', 'to', 'name', 'a', 'few']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The text corpus contains {0:,} tokens".format(token_count))
# Out:
# The text corpus contains 1,929,328 tokens

# %% [markdown]
# ### Assigns the parameters for creating model

# %%
# Dimensions of word vectors.
num_features = 100
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
model = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
model.build_vocab(sentences)
# Out:
# 2020-06-23 16:32:22,212 : INFO : collecting all words and their counts
# 2020-06-23 16:32:22,213 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-06-23 16:32:22,261 : INFO : PROGRESS: at sentence #10000, processed 183934 words, keeping 15182 word types
# 2020-06-23 16:32:22,316 : INFO : PROGRESS: at sentence #20000, processed 371982 words, keeping 22858 word types
# 2020-06-23 16:32:22,368 : INFO : PROGRESS: at sentence #30000, processed 549081 words, keeping 29158 word types
# 2020-06-23 16:32:22,417 : INFO : PROGRESS: at sentence #40000, processed 736285 words, keeping 33577 word types
# 2020-06-23 16:32:22,466 : INFO : PROGRESS: at sentence #50000, processed 920779 words, keeping 38366 word types
# 2020-06-23 16:32:22,522 : INFO : PROGRESS: at sentence #60000, processed 1108806 words, keeping 42633 word types
# 2020-06-23 16:32:22,581 : INFO : PROGRESS: at sentence #70000, processed 1292044 words, keeping 47437 word types
# 2020-06-23 16:32:22,643 : INFO : PROGRESS: at sentence #80000, processed 1476095 words, keeping 50776 word types
# 2020-06-23 16:32:22,697 : INFO : PROGRESS: at sentence #90000, processed 1677919 words, keeping 55220 word types
# 2020-06-23 16:32:22,739 : INFO : PROGRESS: at sentence #100000, processed 1827953 words, keeping 58422 word types
# 2020-06-23 16:32:22,767 : INFO : collected 60314 word types from a corpus of 1929328 raw words and 103823 sentences
# 2020-06-23 16:32:22,768 : INFO : Loading a fresh vocabulary
# 2020-06-23 16:32:22,934 : INFO : effective_min_count=3 retains 23740 unique words (39% of original 60314, drops 36574)
# 2020-06-23 16:32:22,935 : INFO : effective_min_count=3 leaves 1884729 word corpus (97% of original 1929328, drops 44599)
# 2020-06-23 16:32:23,070 : INFO : deleting the raw counts dictionary of 60314 items
# 2020-06-23 16:32:23,072 : INFO : sample=0.001 downsamples 36 most-common words
# 2020-06-23 16:32:23,074 : INFO : downsampling leaves estimated 1534855 word corpus (81.4% of prior 1884729)
# 2020-06-23 16:32:23,158 : INFO : estimated required memory for 23740 words and 100 dimensions: 30862000 bytes
# 2020-06-23 16:32:23,159 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(model.wv.vocab))
# Out:
# Word2Vec vocabulary length: 23740

# %% [markdown]
# Begins training here, time depends on dimensions but under 1000 would be relatively quick

# %%
model.train(sentences, total_examples=model.corpus_count, epochs=model.iter)
# Out:
# /home/max/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# 2020-06-23 16:32:28,847 : INFO : training model with 8 workers on 23740 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-06-23 16:32:29,874 : INFO : EPOCH 1 - PROGRESS: at 18.09% examples, 273795 words/s, in_qsize 14, out_qsize 1
# 2020-06-23 16:32:30,880 : INFO : EPOCH 1 - PROGRESS: at 39.95% examples, 298067 words/s, in_qsize 13, out_qsize 2
# 2020-06-23 16:32:31,902 : INFO : EPOCH 1 - PROGRESS: at 65.22% examples, 325217 words/s, in_qsize 16, out_qsize 0
# 2020-06-23 16:32:32,952 : INFO : EPOCH 1 - PROGRESS: at 89.76% examples, 332409 words/s, in_qsize 15, out_qsize 0
# 2020-06-23 16:32:33,258 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-23 16:32:33,279 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-23 16:32:33,301 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-23 16:32:33,304 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-23 16:32:33,321 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-23 16:32:33,325 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-23 16:32:33,438 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-23 16:32:33,784 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-23 16:32:33,785 : INFO : EPOCH - 1 : training on 1929328 raw words (1520148 effective words) took 4.9s, 308548 effective words/s
# 2020-06-23 16:32:34,818 : INFO : EPOCH 2 - PROGRESS: at 21.79% examples, 329960 words/s, in_qsize 14, out_qsize 1
# 2020-06-23 16:32:35,829 : INFO : EPOCH 2 - PROGRESS: at 47.68% examples, 356235 words/s, in_qsize 15, out_qsize 0
# 2020-06-23 16:32:36,831 : INFO : EPOCH 2 - PROGRESS: at 71.90% examples, 361215 words/s, in_qsize 15, out_qsize 0
# 2020-06-23 16:32:37,848 : INFO : EPOCH 2 - PROGRESS: at 97.28% examples, 362067 words/s, in_qsize 8, out_qsize 0
# 2020-06-23 16:32:37,860 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-23 16:32:37,865 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-23 16:32:37,874 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-23 16:32:37,877 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-23 16:32:37,901 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-23 16:32:37,907 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-23 16:32:37,987 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-23 16:32:38,099 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-23 16:32:38,101 : INFO : EPOCH - 2 : training on 1929328 raw words (1519458 effective words) took 4.3s, 353901 effective words/s
# 2020-06-23 16:32:39,152 : INFO : EPOCH 3 - PROGRESS: at 16.50% examples, 245978 words/s, in_qsize 14, out_qsize 1
# 2020-06-23 16:32:40,173 : INFO : EPOCH 3 - PROGRESS: at 41.09% examples, 300946 words/s, in_qsize 14, out_qsize 1
# 2020-06-23 16:32:41,205 : INFO : EPOCH 3 - PROGRESS: at 65.96% examples, 323390 words/s, in_qsize 15, out_qsize 0
# 2020-06-23 16:32:42,229 : INFO : EPOCH 3 - PROGRESS: at 90.82% examples, 334946 words/s, in_qsize 16, out_qsize 1
# 2020-06-23 16:32:42,445 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-23 16:32:42,458 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-23 16:32:42,493 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-23 16:32:42,494 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-23 16:32:42,517 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-23 16:32:42,534 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-23 16:32:42,554 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-23 16:32:42,624 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-23 16:32:42,624 : INFO : EPOCH - 3 : training on 1929328 raw words (1519937 effective words) took 4.5s, 337386 effective words/s
# 2020-06-23 16:32:43,672 : INFO : EPOCH 4 - PROGRESS: at 24.14% examples, 351739 words/s, in_qsize 15, out_qsize 0
# 2020-06-23 16:32:44,678 : INFO : EPOCH 4 - PROGRESS: at 45.86% examples, 340772 words/s, in_qsize 16, out_qsize 0
# 2020-06-23 16:32:45,688 : INFO : EPOCH 4 - PROGRESS: at 71.46% examples, 354928 words/s, in_qsize 15, out_qsize 0
# 2020-06-23 16:32:46,670 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-23 16:32:46,688 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-23 16:32:46,704 : INFO : EPOCH 4 - PROGRESS: at 98.34% examples, 363759 words/s, in_qsize 5, out_qsize 1
# 2020-06-23 16:32:46,710 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-23 16:32:46,718 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-23 16:32:46,726 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-23 16:32:46,738 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-23 16:32:46,750 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-23 16:32:46,828 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-23 16:32:46,829 : INFO : EPOCH - 4 : training on 1929328 raw words (1519979 effective words) took 4.2s, 362266 effective words/s
# 2020-06-23 16:32:47,854 : INFO : EPOCH 5 - PROGRESS: at 20.76% examples, 313382 words/s, in_qsize 15, out_qsize 0
# 2020-06-23 16:32:48,874 : INFO : EPOCH 5 - PROGRESS: at 44.15% examples, 331022 words/s, in_qsize 13, out_qsize 2
# 2020-06-23 16:32:49,887 : INFO : EPOCH 5 - PROGRESS: at 69.96% examples, 348236 words/s, in_qsize 15, out_qsize 0
# 2020-06-23 16:32:50,929 : INFO : EPOCH 5 - PROGRESS: at 96.74% examples, 355915 words/s, in_qsize 9, out_qsize 0
# 2020-06-23 16:32:50,942 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-06-23 16:32:50,946 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-06-23 16:32:50,957 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-06-23 16:32:50,966 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-06-23 16:32:50,991 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-23 16:32:51,040 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-23 16:32:51,090 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-23 16:32:51,619 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-23 16:32:51,620 : INFO : EPOCH - 5 : training on 1929328 raw words (1519708 effective words) took 4.8s, 317931 effective words/s
# 2020-06-23 16:32:51,621 : INFO : training on a 9646640 raw words (7599230 effective words) took 22.8s, 333691 effective words/s
# (7599230, 9646640)

# %%
# not needed, but simple test for the model
model.wv.most_similar('man')
# Out:
# 2020-06-23 16:32:51,629 : INFO : precomputing L2-norms of word weight vectors
# [('jan', 0.7993326187133789),
#  ('babak', 0.7935115694999695),
#  ('oxford', 0.7895066738128662),
#  ('students', 0.7825140357017517),
#  ('email', 0.7712308764457703),
#  ('Corresponding', 0.7555925846099854),
#  ('obloj', 0.7547800540924072),
#  ('maths', 0.7536329030990601),
#  ('ECGI', 0.7519477009773254),
#  ('mahdavidamghani', 0.7492924332618713)]

# %%
model.wv.vocab
# Out:
# {'v': <gensim.models.keyedvectors.Vocab at 0x7efc99a838d0>,
#  'cs': <gensim.models.keyedvectors.Vocab at 0x7efc99a83e10>,
#  'GT': <gensim.models.keyedvectors.Vocab at 0x7efc99a83cd0>,
#  'Nov': <gensim.models.keyedvectors.Vocab at 0x7efc99a832d0>,
#  'ar': <gensim.models.keyedvectors.Vocab at 0x7efc99a83e50>,
#  'X': <gensim.models.keyedvectors.Vocab at 0x7efc99a83d10>,
#  'V': <gensim.models.keyedvectors.Vocab at 0x7efc99a83b50>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x7efc99a83e90>,
#  'Bayesian': <gensim.models.keyedvectors.Vocab at 0x7efc99a83d50>,
#  'optimization': <gensim.models.keyedvectors.Vocab at 0x7efc99a83fd0>,
#  'approach': <gensim.models.keyedvectors.Vocab at 0x7efc99a83f90>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7efc99a92050>,
#  'compute': <gensim.models.keyedvectors.Vocab at 0x7efc99a92090>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7efc99a92110>,
#  'Nash': <gensim.models.keyedvectors.Vocab at 0x7efc99a92150>,
#  'equilibria': <gensim.models.keyedvectors.Vocab at 0x7efc99a92190>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7efc99a921d0>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7efc99a92210>,
#  'games': <gensim.models.keyedvectors.Vocab at 0x7efc99a92250>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7efc99a92290>,
#  'bandit': <gensim.models.keyedvectors.Vocab at 0x7efc99a922d0>,
#  'feedback': <gensim.models.keyedvectors.Vocab at 0x7efc99a92310>,
#  'Anup': <gensim.models.keyedvectors.Vocab at 0x7efc99a92350>,
#  'Aprem': <gensim.models.keyedvectors.Vocab at 0x7efc99a92390>,
#  'ABSTRACT': <gensim.models.keyedvectors.Vocab at 0x7efc99a923d0>,
#  'Computing': <gensim.models.keyedvectors.Vocab at 0x7efc99a92410>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7efc99a92450>,
#  'strategic': <gensim.models.keyedvectors.Vocab at 0x7efc99a92490>,
#  'multi': <gensim.models.keyedvectors.Vocab at 0x7efc99a924d0>,
#  'agent': <gensim.models.keyedvectors.Vocab at 0x7efc99a92510>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x7efc99a92550>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7efc99a92590>,
#  'challenging': <gensim.models.keyedvectors.Vocab at 0x7efc99a925d0>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x7efc99a92610>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7efc99a92650>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x7efc99a92690>,
#  'Motivated': <gensim.models.keyedvectors.Vocab at 0x7efc99a926d0>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7efc99a92710>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x7efc99a92750>,
#  'exploitation': <gensim.models.keyedvectors.Vocab at 0x7efc99a92790>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x7efc99a927d0>,
#  'resources': <gensim.models.keyedvectors.Vocab at 0x7efc99a92810>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7efc99a92850>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x7efc99a92890>,
#  'considers': <gensim.models.keyedvectors.Vocab at 0x7efc99a928d0>,
#  'above': <gensim.models.keyedvectors.Vocab at 0x7efc99a92910>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7efc99a92950>,
#  'We': <gensim.models.keyedvectors.Vocab at 0x7efc99a92990>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7efc99a929d0>,
#  'framework': <gensim.models.keyedvectors.Vocab at 0x7efc99a92a10>,
#  'obtain': <gensim.models.keyedvectors.Vocab at 0x7efc99a92a50>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x7efc99a92a90>,
#  'algorithms': <gensim.models.keyedvectors.Vocab at 0x7efc99a92ad0>,
#  'solve': <gensim.models.keyedvectors.Vocab at 0x7efc99a92b10>,
#  'finite': <gensim.models.keyedvectors.Vocab at 0x7efc99a92b50>,
#  'discrete': <gensim.models.keyedvectors.Vocab at 0x7efc99a92b90>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7efc99a92bd0>,
#  'spaces': <gensim.models.keyedvectors.Vocab at 0x7efc99a92c10>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7efc99a92c50>,
#  'infinite': <gensim.models.keyedvectors.Vocab at 0x7efc99a92c90>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7efc99a92cd0>,
#  'interval': <gensim.models.keyedvectors.Vocab at 0x7efc99a92d10>,
#  'utilizing': <gensim.models.keyedvectors.Vocab at 0x7efc99a92d50>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x7efc99a92d90>,
#  'Numerical': <gensim.models.keyedvectors.Vocab at 0x7efc99a92dd0>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x7efc99a92e10>,
#  'illustrate': <gensim.models.keyedvectors.Vocab at 0x7efc99a80710>,
#  'efficiency': <gensim.models.keyedvectors.Vocab at 0x7efc99a80a90>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7efc99a80ad0>,
#  'computing': <gensim.models.keyedvectors.Vocab at 0x7efc99a80a50>,
#  'static': <gensim.models.keyedvectors.Vocab at 0x7efc99a809d0>,
#  'linear': <gensim.models.keyedvectors.Vocab at 0x7efc99a80a10>,
#  'dynamic': <gensim.models.keyedvectors.Vocab at 0x7efc99a80750>,
#  'KEYWORDS': <gensim.models.keyedvectors.Vocab at 0x7efc99a80850>,
#  'Potential': <gensim.models.keyedvectors.Vocab at 0x7efc99a80990>,
#  'Gaussian': <gensim.models.keyedvectors.Vocab at 0x7efc99a80610>,
#  'processes': <gensim.models.keyedvectors.Vocab at 0x7efc99a80410>,
#  'INTRODUCTION': <gensim.models.keyedvectors.Vocab at 0x7efc99a808d0>,
#  'Modeling': <gensim.models.keyedvectors.Vocab at 0x7efc99a807d0>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x7efc99a80090>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x7efc99a80310>,
#  'theory': <gensim.models.keyedvectors.Vocab at 0x7efc99a80450>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7efc99a80490>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7efc99a80390>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7efc99a7af90>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7efc99a7aa50>,
#  'Applications': <gensim.models.keyedvectors.Vocab at 0x7efc99a7ab90>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x7efc99a7ac10>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x7efc99a7af50>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7efc99a7ac90>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a7d0>,
#  'phenomena': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a850>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7efc99a7ad10>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a710>,
#  'auctions': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a6d0>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a4d0>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a390>,
#  'formation': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a410>,
#  'behavioral': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a590>,
#  'economics': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a550>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7efc99a7acd0>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7efc99a7ae50>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a650>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7efc99a7add0>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a310>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a2d0>,
#  'solution': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a290>,
#  'concept': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a250>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a190>,
#  'analyze': <gensim.models.keyedvectors.Vocab at 0x7efc99a7a210>,
#  'outcome': <gensim.models.keyedvectors.Vocab at 0x7efcab514d90>,
#  'interaction': <gensim.models.keyedvectors.Vocab at 0x7efcab514590>,
#  'equilibrium': <gensim.models.keyedvectors.Vocab at 0x7efcab514ed0>,
#  'In': <gensim.models.keyedvectors.Vocab at 0x7efcab5147d0>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7efcab514790>,
#  'player': <gensim.models.keyedvectors.Vocab at 0x7efcab514d50>,
#  'benefits': <gensim.models.keyedvectors.Vocab at 0x7efcaa172210>,
#  'deviating': <gensim.models.keyedvectors.Vocab at 0x7efcaa1721d0>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7efcaa172150>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7efcab51d190>,
#  'strategy': <gensim.models.keyedvectors.Vocab at 0x7efcab51d350>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x7efcab51dd10>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7efcaa1cfed0>,
#  'fixed': <gensim.models.keyedvectors.Vocab at 0x7efcaa1cff90>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7efcaa1cfe90>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x7efcaa1cfd50>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7efcaa1cfd90>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x7efcaa1cfc10>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7efcaa1cf950>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7efcaa1cfad0>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7efcaa1cfcd0>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7efc99a92e50>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7efc99a92e90>,
#  'defined': <gensim.models.keyedvectors.Vocab at 0x7efc99a92ed0>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7efc99a92f10>,
#  'refer': <gensim.models.keyedvectors.Vocab at 0x7efc99a92f50>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x7efc99a92f90>,
#  'survey': <gensim.models.keyedvectors.Vocab at 0x7efc99a92fd0>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x7efc99a17050>,
#  'property': <gensim.models.keyedvectors.Vocab at 0x7efc99a17090>,
#  'existence': <gensim.models.keyedvectors.Vocab at 0x7efc99a170d0>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x7efc99a17110>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7efc99a17150>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7efc99a17190>,
#  'optimizing': <gensim.models.keyedvectors.Vocab at 0x7efc99a171d0>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x7efc99a17210>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7efc99a17250>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7efc99a17290>,
#  'extensively': <gensim.models.keyedvectors.Vocab at 0x7efc99a172d0>,
#  'context': <gensim.models.keyedvectors.Vocab at 0x7efc99a17310>,
#  'resource': <gensim.models.keyedvectors.Vocab at 0x7efc99a17350>,
#  'mining': <gensim.models.keyedvectors.Vocab at 0x7efc99a17390>,
#  'fishing': <gensim.models.keyedvectors.Vocab at 0x7efc99a173d0>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7efc99a17410>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7efc99a17450>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x7efc99a17490>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7efc99a174d0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7efc99a17510>,
#  'derives': <gensim.models.keyedvectors.Vocab at 0x7efc99a17550>,
#  'facility': <gensim.models.keyedvectors.Vocab at 0x7efc99a17590>,
#  'proportional': <gensim.models.keyedvectors.Vocab at 0x7efc99a175d0>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7efc99a17610>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7efc99a17650>,
#  'users': <gensim.models.keyedvectors.Vocab at 0x7efc99a17690>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7efc99a176d0>,
#  'An': <gensim.models.keyedvectors.Vocab at 0x7efc99a17710>,
#  'congestion': <gensim.models.keyedvectors.Vocab at 0x7efc99a17750>,
#  'widely': <gensim.models.keyedvectors.Vocab at 0x7efc99a17790>,
#  'understanding': <gensim.models.keyedvectors.Vocab at 0x7efc99a177d0>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7efc99a17810>,
#  'Department': <gensim.models.keyedvectors.Vocab at 0x7efc99a17850>,
#  'Information': <gensim.models.keyedvectors.Vocab at 0x7efc99a17890>,
#  'Engineering': <gensim.models.keyedvectors.Vocab at 0x7efc99a178d0>,
#  'University': <gensim.models.keyedvectors.Vocab at 0x7efc99a17910>,
#  'Oxford': <gensim.models.keyedvectors.Vocab at 0x7efc99a17950>,
#  'UK': <gensim.models.keyedvectors.Vocab at 0x7efc99a17990>,
#  'Email': <gensim.models.keyedvectors.Vocab at 0x7efc99a179d0>,
#  'robots': <gensim.models.keyedvectors.Vocab at 0x7efc99a17a10>,
#  'ox': <gensim.models.keyedvectors.Vocab at 0x7efc99a17a50>,
#  'ac': <gensim.models.keyedvectors.Vocab at 0x7efc99a17a90>,
#  'uk': <gensim.models.keyedvectors.Vocab at 0x7efc99a17ad0>,
#  'Stephen': <gensim.models.keyedvectors.Vocab at 0x7efc99a17b10>,
#  'J': <gensim.models.keyedvectors.Vocab at 0x7efc99a17b50>,
#  'Roberts': <gensim.models.keyedvectors.Vocab at 0x7efc99a17b90>,
#  'Man': <gensim.models.keyedvectors.Vocab at 0x7efc99a17bd0>,
#  'Institute': <gensim.models.keyedvectors.Vocab at 0x7efc99a17c10>,
#  'Quantitative': <gensim.models.keyedvectors.Vocab at 0x7efc99a17c50>,
#  'Finance': <gensim.models.keyedvectors.Vocab at 0x7efc99a17c90>,
#  'Mind': <gensim.models.keyedvectors.Vocab at 0x7efc99a17cd0>,
#  'Foundry': <gensim.models.keyedvectors.Vocab at 0x7efc99a17d10>,
#  'Ltd': <gensim.models.keyedvectors.Vocab at 0x7efc99a17d50>,
#  'sjrob': <gensim.models.keyedvectors.Vocab at 0x7efc99a17d90>,
#  'System': <gensim.models.keyedvectors.Vocab at 0x7efc99a17dd0>,
#  'Operator': <gensim.models.keyedvectors.Vocab at 0x7efc99a17e10>,
#  'Agent': <gensim.models.keyedvectors.Vocab at 0x7efc99a17e50>,
#  'N': <gensim.models.keyedvectors.Vocab at 0x7efc99a17e90>,
#  'Secure': <gensim.models.keyedvectors.Vocab at 0x7efc99a17ed0>,
#  'Figure': <gensim.models.keyedvectors.Vocab at 0x7efc99a17f10>,
#  'Example': <gensim.models.keyedvectors.Vocab at 0x7efc99a17f50>,
#  'utility': <gensim.models.keyedvectors.Vocab at 0x7efc99a17f90>,
#  'cloud': <gensim.models.keyedvectors.Vocab at 0x7efc99a17fd0>,
#  'Each': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a050>,
#  'secure': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a090>,
#  'disclose': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a0d0>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a110>,
#  'private': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a150>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a190>,
#  'operator': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a1d0>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a210>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a250>,
#  'realized': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a290>,
#  'values': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a2d0>,
#  'functions': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a310>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a350>,
#  'transportation': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a390>,
#  'urban': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a3d0>,
#  'areas': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a410>,
#  'influence': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a450>,
#  'networks': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a490>,
#  'decision': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a4d0>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a510>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a550>,
#  'uncertainty': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a590>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a5d0>,
#  'proposed': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a610>,
#  'preference': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a650>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a690>,
#  'finds': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a6d0>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a710>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a750>,
#  'wireless': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a790>,
#  'cognitive': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a7d0>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a810>,
#  'There': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a850>,
#  'extensive': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a890>,
#  'literature': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a8d0>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a910>,
#  'techniques': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a950>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a990>,
#  'However': <gensim.models.keyedvectors.Vocab at 0x7efc99a1a9d0>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7efc99a1aa10>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7efc99a1aa50>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x7efc99a1aa90>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7efc99a1aad0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ab10>,
#  'evaluate': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ab50>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ab90>,
#  'Other': <gensim.models.keyedvectors.Vocab at 0x7efc99a1abd0>,
#  'examples': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ac10>,
#  'extraction': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ac50>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ac90>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7efc99a1acd0>,
#  'regulator': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ad10>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ad50>,
#  'takes': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ad90>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7efc99a1add0>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ae10>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ae50>,
#  'players': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ae90>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7efc99a1aed0>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7efc99a1af10>,
#  'actions': <gensim.models.keyedvectors.Vocab at 0x7efc99a1af50>,
#  'To': <gensim.models.keyedvectors.Vocab at 0x7efc99a1af90>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7efc99a1afd0>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d050>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d090>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d0d0>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d110>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d150>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d190>,
#  'modeled': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d1d0>,
#  'Hence': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d210>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d250>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d290>,
#  'Main': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d2d0>,
#  'Organization': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d310>,
#  'Section': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d350>,
#  'provides': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d390>,
#  'brief': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d3d0>,
#  'introduction': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d410>,
#  'properties': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d450>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d490>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d4d0>,
#  'parametric': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d510>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d550>,
#  'unknown': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d590>,
#  'efficiently': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d5d0>,
#  'summarizes': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d610>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d650>,
#  'regression': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d690>,
#  'adopted': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d6d0>,
#  'Since': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d710>,
#  'characterized': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d750>,
#  'impose': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d790>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d7d0>,
#  'formulation': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d810>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d850>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d890>,
#  'imposed': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d8d0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d910>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d950>,
#  'observed': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d990>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7efc99a1d9d0>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x7efc99a1da10>,
#  'measured': <gensim.models.keyedvectors.Vocab at 0x7efc99a1da50>,
#  'commonly': <gensim.models.keyedvectors.Vocab at 0x7efc99a1da90>,
#  'referred': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dad0>,
#  'This': <gensim.models.keyedvectors.Vocab at 0x7efc99a1db10>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7efc99a1db50>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7efc99a1db90>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dbd0>,
#  'algorithm': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dc10>,
#  'Algorithm': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dc50>,
#  'sets': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dc90>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dcd0>,
#  'Similarly': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dd10>,
#  'continuous': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dd50>,
#  'When': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dd90>,
#  'noisy': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ddd0>,
#  'integral': <gensim.models.keyedvectors.Vocab at 0x7efc99a1de10>,
#  'gradients': <gensim.models.keyedvectors.Vocab at 0x7efc99a1de50>,
#  'presents': <gensim.models.keyedvectors.Vocab at 0x7efc99a1de90>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x7efc99a1ded0>,
#  'simultaneously': <gensim.models.keyedvectors.Vocab at 0x7efc99a1df10>,
#  'estimates': <gensim.models.keyedvectors.Vocab at 0x7efc99a1df50>,
#  'gradient': <gensim.models.keyedvectors.Vocab at 0x7efc99a1df90>,
#  'optimizes': <gensim.models.keyedvectors.Vocab at 0x7efc99a1dfd0>,
#  'iii': <gensim.models.keyedvectors.Vocab at 0x7efc99a21050>,
#  'numerical': <gensim.models.keyedvectors.Vocab at 0x7efc99a21090>,
#  'illustrating': <gensim.models.keyedvectors.Vocab at 0x7efc99a210d0>,
#  'compared': <gensim.models.keyedvectors.Vocab at 0x7efc99a21110>,
#  'existing': <gensim.models.keyedvectors.Vocab at 0x7efc99a21150>,
#  'Concluding': <gensim.models.keyedvectors.Vocab at 0x7efc99a21190>,
#  'remarks': <gensim.models.keyedvectors.Vocab at 0x7efc99a211d0>,
#  'offered': <gensim.models.keyedvectors.Vocab at 0x7efc99a21210>,
#  'Context': <gensim.models.keyedvectors.Vocab at 0x7efc99a21250>,
#  'Related': <gensim.models.keyedvectors.Vocab at 0x7efc99a21290>,
#  'Literature': <gensim.models.keyedvectors.Vocab at 0x7efc99a212d0>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x7efc99a21310>,
#  'regret': <gensim.models.keyedvectors.Vocab at 0x7efc99a21350>,
#  'classical': <gensim.models.keyedvectors.Vocab at 0x7efc99a21390>,
#  'chooses': <gensim.models.keyedvectors.Vocab at 0x7efc99a213d0>,
#  'mixed': <gensim.models.keyedvectors.Vocab at 0x7efc99a21410>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7efc99a21450>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7efc99a21490>,
#  'obtains': <gensim.models.keyedvectors.Vocab at 0x7efc99a214d0>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7efc99a21510>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7efc99a21550>,
#  'associated': <gensim.models.keyedvectors.Vocab at 0x7efc99a21590>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7efc99a215d0>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x7efc99a21610>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7efc99a21650>,
#  'obtained': <gensim.models.keyedvectors.Vocab at 0x7efc99a21690>,
#  'chosen': <gensim.models.keyedvectors.Vocab at 0x7efc99a216d0>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x7efc99a21710>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7efc99a21750>,
#  'exponential': <gensim.models.keyedvectors.Vocab at 0x7efc99a21790>,
#  'multiplicative': <gensim.models.keyedvectors.Vocab at 0x7efc99a217d0>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x7efc99a21810>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7efc99a21850>,
#  'converges': <gensim.models.keyedvectors.Vocab at 0x7efc99a21890>,
#  'Inferring': <gensim.models.keyedvectors.Vocab at 0x7efc99a218d0>,
#  'utilities': <gensim.models.keyedvectors.Vocab at 0x7efc99a21910>,
#  'agents': <gensim.models.keyedvectors.Vocab at 0x7efc99a21950>,
#  'revealed': <gensim.models.keyedvectors.Vocab at 0x7efc99a21990>,
#  'micro': <gensim.models.keyedvectors.Vocab at 0x7efc99a219d0>,
#  'extended': <gensim.models.keyedvectors.Vocab at 0x7efc99a21a10>,
#  'multiagent': <gensim.models.keyedvectors.Vocab at 0x7efc99a21a50>,
#  'comparison': <gensim.models.keyedvectors.Vocab at 0x7efc99a21a90>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x7efc99a21ad0>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7efc99a21b10>,
#  'characterizing': <gensim.models.keyedvectors.Vocab at 0x7efc99a21b50>,
#  'Notation': <gensim.models.keyedvectors.Vocab at 0x7efc99a21b90>,
#  'vectors': <gensim.models.keyedvectors.Vocab at 0x7efc99a21bd0>,
#  'denoted': <gensim.models.keyedvectors.Vocab at 0x7efc99a21c10>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x7efc99a21c50>,
#  'letters': <gensim.models.keyedvectors.Vocab at 0x7efc99a21c90>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x7efc99a21cd0>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7efc99a21d10>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x7efc99a21d50>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7efc99a21d90>,
#  'matrices': <gensim.models.keyedvectors.Vocab at 0x7efc99a21dd0>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x7efc99a21e10>,
#  'K': <gensim.models.keyedvectors.Vocab at 0x7efc99a21e50>,
#  'For': <gensim.models.keyedvectors.Vocab at 0x7efc99a21e90>,
#  'vector': <gensim.models.keyedvectors.Vocab at 0x7efc99a21ed0>,
#  'denotes': <gensim.models.keyedvectors.Vocab at 0x7efc99a21f10>,
#  'transpose': <gensim.models.keyedvectors.Vocab at 0x7efc99a21f50>,
#  'f': <gensim.models.keyedvectors.Vocab at 0x7efc99a21f90>,
#  'derivative': <gensim.models.keyedvectors.Vocab at 0x7efc99a21fd0>,
#  'indexed': <gensim.models.keyedvectors.Vocab at 0x7efc99a24050>,
#  'j': <gensim.models.keyedvectors.Vocab at 0x7efc99a24090>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x7efc99a240d0>,
#  'denote': <gensim.models.keyedvectors.Vocab at 0x7efc99a24110>,
#  'sequence': <gensim.models.keyedvectors.Vocab at 0x7efc99a24150>,
#  'indices': <gensim.models.keyedvectors.Vocab at 0x7efc99a24190>,
#  'component': <gensim.models.keyedvectors.Vocab at 0x7efc99a241d0>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x7efc99a24210>,
#  'corresponding': <gensim.models.keyedvectors.Vocab at 0x7efc99a24250>,
#  'subscript': <gensim.models.keyedvectors.Vocab at 0x7efc99a24290>,
#  'index': <gensim.models.keyedvectors.Vocab at 0x7efc99a242d0>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7efc99a24310>,
#  'superscript': <gensim.models.keyedvectors.Vocab at 0x7efc99a24350>,
#  'Time': <gensim.models.keyedvectors.Vocab at 0x7efc99a24390>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7efc99a243d0>,
#  'Finally': <gensim.models.keyedvectors.Vocab at 0x7efc99a24410>,
#  'symbol': <gensim.models.keyedvectors.Vocab at 0x7efc99a24450>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7efc99a24490>,
#  'distributed': <gensim.models.keyedvectors.Vocab at 0x7efc99a244d0>,
#  'PRELIMINARIES': <gensim.models.keyedvectors.Vocab at 0x7efc99a24510>,
#  'introduce': <gensim.models.keyedvectors.Vocab at 0x7efc99a24550>,
#  'Sec': <gensim.models.keyedvectors.Vocab at 0x7efc99a24590>,
#  'summarize': <gensim.models.keyedvectors.Vocab at 0x7efc99a245d0>,
#  'Games': <gensim.models.keyedvectors.Vocab at 0x7efc99a24610>,
#  'Consider': <gensim.models.keyedvectors.Vocab at 0x7efc99a24650>,
#  'Player': <gensim.models.keyedvectors.Vocab at 0x7efc99a24690>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7efc99a246d0>,
#  'Let': <gensim.models.keyedvectors.Vocab at 0x7efc99a24710>,
#  'xy': <gensim.models.keyedvectors.Vocab at 0x7efc99a24750>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7efc99a24790>,
#  'payoff': <gensim.models.keyedvectors.Vocab at 0x7efc99a247d0>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x7efc99a24810>,
#  'uj': <gensim.models.keyedvectors.Vocab at 0x7efc99a24850>,
#  'R': <gensim.models.keyedvectors.Vocab at 0x7efc99a24890>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7efc99a248d0>,
#  'objective': <gensim.models.keyedvectors.Vocab at 0x7efc99a24910>,
#  'maximize': <gensim.models.keyedvectors.Vocab at 0x7efc99a24950>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x7efc99a24990>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x7efc99a249d0>,
#  'EX': <gensim.models.keyedvectors.Vocab at 0x7efc99a24a10>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7efc99a24a50>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7efc99a24a90>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7efc99a24ad0>,
#  'argmax': <gensim.models.keyedvectors.Vocab at 0x7efc99a24b10>,
#  'Vi': <gensim.models.keyedvectors.Vocab at 0x7efc99a24b50>,
#  'DEFINITION': <gensim.models.keyedvectors.Vocab at 0x7efc99a24b90>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7efc99a24bd0>,
#  'exists': <gensim.models.keyedvectors.Vocab at 0x7efc99a24c10>,
#  'ui': <gensim.models.keyedvectors.Vocab at 0x7efc99a24c50>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x7efc99a24c90>,
#  'Uj': <gensim.models.keyedvectors.Vocab at 0x7efc99a24cd0>,
#  'Z': <gensim.models.keyedvectors.Vocab at 0x7efc99a24d10>,
#  'xi': <gensim.models.keyedvectors.Vocab at 0x7efc99a24d50>,
#  'P': <gensim.models.keyedvectors.Vocab at 0x7efc99a24d90>,
#  'z': <gensim.models.keyedvectors.Vocab at 0x7efc99a24dd0>,
#  'Vy': <gensim.models.keyedvectors.Vocab at 0x7efc99a24e10>,
#  'Xj': <gensim.models.keyedvectors.Vocab at 0x7efc99a24e50>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x7efc99a24e90>,
#  'ie': <gensim.models.keyedvectors.Vocab at 0x7efc99a24ed0>,
#  'Another': <gensim.models.keyedvectors.Vocab at 0x7efc99a24f10>,
#  'Finite': <gensim.models.keyedvectors.Vocab at 0x7efc99a24f50>,
#  'Improvement': <gensim.models.keyedvectors.Vocab at 0x7efc99a24f90>,
#  'Path': <gensim.models.keyedvectors.Vocab at 0x7efc99a24fd0>,
#  'FIP': <gensim.models.keyedvectors.Vocab at 0x7efc99a28050>,
#  'xk': <gensim.models.keyedvectors.Vocab at 0x7efc99a28090>,
#  'yee': <gensim.models.keyedvectors.Vocab at 0x7efc99a280d0>,
#  'unique': <gensim.models.keyedvectors.Vocab at 0x7efc99a28110>,
#  'deviator': <gensim.models.keyedvectors.Vocab at 0x7efc99a28150>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7efc99a28190>,
#  'Given': <gensim.models.keyedvectors.Vocab at 0x7efc99a281d0>,
#  'path': <gensim.models.keyedvectors.Vocab at 0x7efc99a28210>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x7efc99a28250>,
#  'xf': <gensim.models.keyedvectors.Vocab at 0x7efc99a28290>,
#  'L': <gensim.models.keyedvectors.Vocab at 0x7efc99a282d0>,
#  'improvement': <gensim.models.keyedvectors.Vocab at 0x7efc99a28310>,
#  'Vk': <gensim.models.keyedvectors.Vocab at 0x7efc99a28350>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x7efc99a28390>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7efc99a283d0>,
#  'Infinite': <gensim.models.keyedvectors.Vocab at 0x7efc99a28410>,
#  'lemma': <gensim.models.keyedvectors.Vocab at 0x7efc99a28450>,
#  'equivalent': <gensim.models.keyedvectors.Vocab at 0x7efc99a28490>,
#  'definition': <gensim.models.keyedvectors.Vocab at 0x7efc99a284d0>,
#  'LEMMA': <gensim.models.keyedvectors.Vocab at 0x7efc99a28510>,
#  'intervals': <gensim.models.keyedvectors.Vocab at 0x7efc99a28550>,
#  'numbers': <gensim.models.keyedvectors.Vocab at 0x7efc99a28590>,
#  'Suppose': <gensim.models.keyedvectors.Vocab at 0x7efc99a285d0>,
#  'bounded': <gensim.models.keyedvectors.Vocab at 0x7efc99a28610>,
#  'continuously': <gensim.models.keyedvectors.Vocab at 0x7efc99a28650>,
#  'differentiable': <gensim.models.keyedvectors.Vocab at 0x7efc99a28690>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7efc99a286d0>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7efc99a28710>,
#  'Ou': <gensim.models.keyedvectors.Vocab at 0x7efc99a28750>,
#  'O': <gensim.models.keyedvectors.Vocab at 0x7efc99a28790>,
#  'Vx': <gensim.models.keyedvectors.Vocab at 0x7efc99a287d0>,
#  'OX': <gensim.models.keyedvectors.Vocab at 0x7efc99a28810>,
#  'Similar': <gensim.models.keyedvectors.Vocab at 0x7efc99a28850>,
#  'approximate': <gensim.models.keyedvectors.Vocab at 0x7efc99a28890>,
#  'Population': <gensim.models.keyedvectors.Vocab at 0x7efc99a288d0>,
#  'Extension': <gensim.models.keyedvectors.Vocab at 0x7efc99a28910>,
#  'population': <gensim.models.keyedvectors.Vocab at 0x7efc99a28950>,
#  'ongoing': <gensim.models.keyedvectors.Vocab at 0x7efc99a28990>,
#  'implies': <gensim.models.keyedvectors.Vocab at 0x7efc99a289d0>,
#  'achieved': <gensim.models.keyedvectors.Vocab at 0x7efc99a28a10>,
#  'myopic': <gensim.models.keyedvectors.Vocab at 0x7efc99a28a50>,
#  'policy': <gensim.models.keyedvectors.Vocab at 0x7efc99a28a90>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7efc99a28ad0>,
#  'Processes': <gensim.models.keyedvectors.Vocab at 0x7efc99a28b10>,
#  'stochastic': <gensim.models.keyedvectors.Vocab at 0x7efc99a28b50>,
#  'collection': <gensim.models.keyedvectors.Vocab at 0x7efc99a28b90>,
#  'F': <gensim.models.keyedvectors.Vocab at 0x7efc99a28bd0>,
#  'Fo': <gensim.models.keyedvectors.Vocab at 0x7efc99a28c10>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7efc99a28c50>,
#  'advantage': <gensim.models.keyedvectors.Vocab at 0x7efc99a28c90>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7efc99a28cd0>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x7efc99a28d10>,
#  'specified': <gensim.models.keyedvectors.Vocab at 0x7efc99a28d50>,
#  'covariance': <gensim.models.keyedvectors.Vocab at 0x7efc99a28d90>,
#  'follows': <gensim.models.keyedvectors.Vocab at 0x7efc99a28dd0>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x7efc99a28e10>,
#  'ELf': <gensim.models.keyedvectors.Vocab at 0x7efc99a28e50>,
#  'E': <gensim.models.keyedvectors.Vocab at 0x7efc99a28e90>,
#  'hyper': <gensim.models.keyedvectors.Vocab at 0x7efc99a28ed0>,
#  'parameters': <gensim.models.keyedvectors.Vocab at 0x7efc99a28f10>,
#  'encode': <gensim.models.keyedvectors.Vocab at 0x7efc99a28f50>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x7efc99a28f90>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x7efc99a28fd0>,
#  'GP': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b050>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b090>,
#  'Kk': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b0d0>,
#  'uoe': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b110>,
#  'bea': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b150>,
#  'matrix': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b190>,
#  'Kn': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b1d0>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b210>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b250>,
#  'jp': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b290>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b2d0>,
#  'predictive': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b310>,
#  'px': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b350>,
#  'variance': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b390>,
#  'Ue': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b3d0>,
#  'KI': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b410>,
#  'Ky': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b450>,
#  'pp': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b490>,
#  'Kx': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b4d0>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b510>,
#  'xn': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b550>,
#  'Kyx': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b590>,
#  'affine': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b5d0>,
#  'transformation': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b610>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b650>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b690>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b6d0>,
#  'differential': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b710>,
#  'operators': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b750>,
#  'Of': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b790>,
#  'lr': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b7d0>,
#  'Af': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b810>,
#  'Ox': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b850>,
#  'D': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b890>,
#  'Ki': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b8d0>,
#  'xX': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b910>,
#  'cov': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b950>,
#  'KP': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b990>,
#  'yf': <gensim.models.keyedvectors.Vocab at 0x7efc99a2b9d0>,
#  'OK': <gensim.models.keyedvectors.Vocab at 0x7efc99a2ba10>,
#  'introduced': <gensim.models.keyedvectors.Vocab at 0x7efc99a2ba50>,
#  'NASH': <gensim.models.keyedvectors.Vocab at 0x7efc99a2ba90>,
#  'FOR': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bad0>,
#  'FINITE': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bb10>,
#  'GAMES': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bb50>,
#  'Process': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bb90>,
#  'Le': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bbd0>,
#  'yk': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bc10>,
#  'below': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bc50>,
#  'zero': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bc90>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bcd0>,
#  'noise': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bd10>,
#  'Ek': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bd50>,
#  'propose': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bd90>,
#  'sequential': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bdd0>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x7efc99a2be10>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x7efc99a2be50>,
#  'YE': <gensim.models.keyedvectors.Vocab at 0x7efc99a2be90>,
#  'Xk': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bed0>,
#  'oe': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bf10>,
#  'xj': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bf50>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bf90>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7efc99a2bfd0>,
#  'improves': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f050>,
#  'abuse': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f090>,
#  'notation': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f0d0>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f110>,
#  'hence': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f150>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f190>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f1d0>,
#  'lookahead': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f210>,
#  'criterion': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f250>,
#  'automatically': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f290>,
#  'promotes': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f2d0>,
#  'trade': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f310>,
#  'exploration': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f350>,
#  'discussion': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f390>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f3d0>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f410>,
#  'selecting': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f450>,
#  'maximizes': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f490>,
#  'wi': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f4d0>,
#  'ek': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f510>,
#  'eek': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f550>,
#  'lay': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f590>,
#  'Define': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f5d0>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f610>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f650>,
#  'AY': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f690>,
#  'Aw': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f6d0>,
#  'Au': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f710>,
#  'ree': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f750>,
#  'Aya': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f790>,
#  'Ay': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f7d0>,
#  'Ye': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f810>,
#  'ko': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f850>,
#  'Bo': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f890>,
#  'ji': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f8d0>,
#  'Bu': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f910>,
#  'B': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f950>,
#  'differencing': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f990>,
#  'Bi': <gensim.models.keyedvectors.Vocab at 0x7efc99a2f9d0>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fa10>,
#  'partition': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fa50>,
#  'My': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fa90>,
#  'Ko': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fad0>,
#  'posterior': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fb10>,
#  'observations': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fb50>,
#  'UZ': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fb90>,
#  'le': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fbd0>,
#  'fir': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fc10>,
#  'os': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fc50>,
#  'oF': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fc90>,
#  'Ris': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fcd0>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fd10>,
#  'ference': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fd50>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fd90>,
#  'variables': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fdd0>,
#  'wz': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fe10>,
#  'nz': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fe50>,
#  'oz': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fe90>,
#  'exp': <gensim.models.keyedvectors.Vocab at 0x7efc99a2fed0>,
#  'Choose': <gensim.models.keyedvectors.Vocab at 0x7efc99a2ff10>,
#  'initial': <gensim.models.keyedvectors.Vocab at 0x7efc99a2ff50>,
#  'fork': <gensim.models.keyedvectors.Vocab at 0x7efc99a2ff90>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7efc99a2ffd0>,
#  'Construct': <gensim.models.keyedvectors.Vocab at 0x7efc99a33050>,
#  'yh': <gensim.models.keyedvectors.Vocab at 0x7efc99a33090>,
#  'Compute': <gensim.models.keyedvectors.Vocab at 0x7efc99a330d0>,
#  'according': <gensim.models.keyedvectors.Vocab at 0x7efc99a33110>,
#  'partitions': <gensim.models.keyedvectors.Vocab at 0x7efc99a33150>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7efc99a33190>,
#  'kel': <gensim.models.keyedvectors.Vocab at 0x7efc99a331d0>,
#  'section': <gensim.models.keyedvectors.Vocab at 0x7efc99a33210>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7efc99a33250>,
#  'generating': <gensim.models.keyedvectors.Vocab at 0x7efc99a33290>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7efc99a332d0>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x7efc99a33310>,
#  'requires': <gensim.models.keyedvectors.Vocab at 0x7efc99a33350>,
#  'estimating': <gensim.models.keyedvectors.Vocab at 0x7efc99a33390>,
#  'choosing': <gensim.models.keyedvectors.Vocab at 0x7efc99a333d0>,
#  'appropriate': <gensim.models.keyedvectors.Vocab at 0x7efc99a33410>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x7efc99a33450>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7efc99a33490>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7efc99a334d0>,
#  'steps': <gensim.models.keyedvectors.Vocab at 0x7efc99a33510>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x7efc99a33550>,
#  'respectively': <gensim.models.keyedvectors.Vocab at 0x7efc99a33590>,
#  'Estimating': <gensim.models.keyedvectors.Vocab at 0x7efc99a335d0>,
#  'Auk': <gensim.models.keyedvectors.Vocab at 0x7efc99a33610>,
#  'rk': <gensim.models.keyedvectors.Vocab at 0x7efc99a33650>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x7efc99a33690>,
#  'rt': <gensim.models.keyedvectors.Vocab at 0x7efc99a336d0>,
#  'Then': <gensim.models.keyedvectors.Vocab at 0x7efc99a33710>,
#  'OT': <gensim.models.keyedvectors.Vocab at 0x7efc99a33750>,
#  'equality': <gensim.models.keyedvectors.Vocab at 0x7efc99a33790>,
#  'scalar': <gensim.models.keyedvectors.Vocab at 0x7efc99a337d0>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x7efc99a33810>,
#  'depends': <gensim.models.keyedvectors.Vocab at 0x7efc99a33850>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7efc99a33890>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7efc99a338d0>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7efc99a33910>,
#  'written': <gensim.models.keyedvectors.Vocab at 0x7efc99a33950>,
#  'Da': <gensim.models.keyedvectors.Vocab at 0x7efc99a33990>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7efc99a339d0>,
#  'dr': <gensim.models.keyedvectors.Vocab at 0x7efc99a33a10>,
#  'Or': <gensim.models.keyedvectors.Vocab at 0x7efc99a33a50>,
#  'ae': <gensim.models.keyedvectors.Vocab at 0x7efc99a33a90>,
#  'aaa': <gensim.models.keyedvectors.Vocab at 0x7efc99a33ad0>,
#  'formulae': <gensim.models.keyedvectors.Vocab at 0x7efc99a33b10>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7efc99a33b50>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7efc99a33b90>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7efc99a33bd0>,
#  'interpreted': <gensim.models.keyedvectors.Vocab at 0x7efc99a33c10>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x7efc99a33c50>,
#  'direction': <gensim.models.keyedvectors.Vocab at 0x7efc99a33c90>,
#  'diag': <gensim.models.keyedvectors.Vocab at 0x7efc99a33cd0>,
#  'Ax': <gensim.models.keyedvectors.Vocab at 0x7efc99a33d10>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7efc99a33d50>,
#  'Using': <gensim.models.keyedvectors.Vocab at 0x7efc99a33d90>,
#  'au': <gensim.models.keyedvectors.Vocab at 0x7efc99a33dd0>,
#  'foo': <gensim.models.keyedvectors.Vocab at 0x7efc99a33e10>,
#  'All': <gensim.models.keyedvectors.Vocab at 0x7efc99a33e50>,
#  'Hadamard': <gensim.models.keyedvectors.Vocab at 0x7efc99a33e90>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x7efc99a33ed0>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7efc99a33f10>,
#  'AU': <gensim.models.keyedvectors.Vocab at 0x7efc99a33f50>,
#  'ge': <gensim.models.keyedvectors.Vocab at 0x7efc99a33f90>,
#  'Hee': <gensim.models.keyedvectors.Vocab at 0x7efc99a33fd0>,
#  'joint': <gensim.models.keyedvectors.Vocab at 0x7efc99a36050>,
#  'equal': <gensim.models.keyedvectors.Vocab at 0x7efc99a36090>,
#  'uP': <gensim.models.keyedvectors.Vocab at 0x7efc99a360d0>,
#  'ye': <gensim.models.keyedvectors.Vocab at 0x7efc99a36110>,
#  'fo': <gensim.models.keyedvectors.Vocab at 0x7efc99a36150>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x7efc99a36190>,
#  'fk': <gensim.models.keyedvectors.Vocab at 0x7efc99a361d0>,
#  'ry': <gensim.models.keyedvectors.Vocab at 0x7efc99a36210>,
#  'dt': <gensim.models.keyedvectors.Vocab at 0x7efc99a36250>,
#  'DD': <gensim.models.keyedvectors.Vocab at 0x7efc99a36290>,
#  'Tk': <gensim.models.keyedvectors.Vocab at 0x7efc99a362d0>,
#  'Ke': <gensim.models.keyedvectors.Vocab at 0x7efc99a36310>,
#  'ey': <gensim.models.keyedvectors.Vocab at 0x7efc99a36350>,
#  'rK': <gensim.models.keyedvectors.Vocab at 0x7efc99a36390>,
#  'described': <gensim.models.keyedvectors.Vocab at 0x7efc99a363d0>,
#  'pP': <gensim.models.keyedvectors.Vocab at 0x7efc99a36410>,
#  'yt': <gensim.models.keyedvectors.Vocab at 0x7efc99a36450>,
#  'yo': <gensim.models.keyedvectors.Vocab at 0x7efc99a36490>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x7efc99a364d0>,
#  'Y': <gensim.models.keyedvectors.Vocab at 0x7efc99a36510>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7efc99a36550>,
#  'Having': <gensim.models.keyedvectors.Vocab at 0x7efc99a36590>,
#  'estimated': <gensim.models.keyedvectors.Vocab at 0x7efc99a365d0>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x7efc99a36610>,
#  'Choosing': <gensim.models.keyedvectors.Vocab at 0x7efc99a36650>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x7efc99a36690>,
#  'Hessian': <gensim.models.keyedvectors.Vocab at 0x7efc99a366d0>,
#  'obtaining': <gensim.models.keyedvectors.Vocab at 0x7efc99a36710>,
#  'derivatives': <gensim.models.keyedvectors.Vocab at 0x7efc99a36750>,
#  'computationally': <gensim.models.keyedvectors.Vocab at 0x7efc99a36790>,
#  'practical': <gensim.models.keyedvectors.Vocab at 0x7efc99a367d0>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x7efc99a36810>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x7efc99a36850>,
#  'tries': <gensim.models.keyedvectors.Vocab at 0x7efc99a36890>,
#  'candidate': <gensim.models.keyedvectors.Vocab at 0x7efc99a368d0>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x7efc99a36910>,
# ...
#  'parameter': <gensim.models.keyedvectors.Vocab at 0x7efc99a36cd0>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7efc99a36d10>,
#  'Wolfe': <gensim.models.keyedvectors.Vocab at 0x7efc99a36d50>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7efc99a36d90>,
#  'ensures': <gensim.models.keyedvectors.Vocab at 0x7efc99a36dd0>,
#  'convergence': <gensim.models.keyedvectors.Vocab at 0x7efc99a36e10>,
#  'S': <gensim.models.keyedvectors.Vocab at 0x7efc99a36e50>,
#  'ascent': <gensim.models.keyedvectors.Vocab at 0x7efc99a36e90>,
#  'withO': <gensim.models.keyedvectors.Vocab at 0x7efc99a36ed0>,
#  'cy': <gensim.models.keyedvectors.Vocab at 0x7efc99a36f10>,
#  'cg': <gensim.models.keyedvectors.Vocab at 0x7efc99a36f50>,
#  'Sufficient': <gensim.models.keyedvectors.Vocab at 0x7efc99a36f90>,
#  'Increase': <gensim.models.keyedvectors.Vocab at 0x7efc99a36fd0>,
#  'cd': <gensim.models.keyedvectors.Vocab at 0x7efc99a39050>,
#  'Curvature': <gensim.models.keyedvectors.Vocab at 0x7efc99a39090>,
#  'Condition': <gensim.models.keyedvectors.Vocab at 0x7efc99a390d0>,
#  'cof': <gensim.models.keyedvectors.Vocab at 0x7efc99a39110>,
#  'condition': <gensim.models.keyedvectors.Vocab at 0x7efc99a39150>,
#  'sufficient': <gensim.models.keyedvectors.Vocab at 0x7efc99a39190>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x7efc99a391d0>,
#  'slope': <gensim.models.keyedvectors.Vocab at 0x7efc99a39210>,
#  'decreases': <gensim.models.keyedvectors.Vocab at 0x7efc99a39250>,
#  'Typically': <gensim.models.keyedvectors.Vocab at 0x7efc99a39290>,
#  'cz': <gensim.models.keyedvectors.Vocab at 0x7efc99a392d0>,
#  'probabilistic': <gensim.models.keyedvectors.Vocab at 0x7efc99a39310>,
#  'probability': <gensim.models.keyedvectors.Vocab at 0x7efc99a39350>,
#  'Defn': <gensim.models.keyedvectors.Vocab at 0x7efc99a39390>,
#  'satisfied': <gensim.models.keyedvectors.Vocab at 0x7efc99a393d0>,
#  'candidates': <gensim.models.keyedvectors.Vocab at 0x7efc99a39410>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7efc99a39450>,
#  'threshold': <gensim.models.keyedvectors.Vocab at 0x7efc99a39490>,
#  'From': <gensim.models.keyedvectors.Vocab at 0x7efc99a394d0>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x7efc99a39510>,
#  'modelling': <gensim.models.keyedvectors.Vocab at 0x7efc99a39550>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7efc99a39590>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x7efc99a395d0>,
#  'pi': <gensim.models.keyedvectors.Vocab at 0x7efc99a39610>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x7efc99a39650>,
#  'Fala': <gensim.models.keyedvectors.Vocab at 0x7efc99a39690>,
#  'basis': <gensim.models.keyedvectors.Vocab at 0x7efc99a396d0>,
#  'define': <gensim.models.keyedvectors.Vocab at 0x7efc99a39710>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x7efc99a39750>,
#  'dx': <gensim.models.keyedvectors.Vocab at 0x7efc99a39790>,
#  'Ul': <gensim.models.keyedvectors.Vocab at 0x7efc99a397d0>,
#  'KD': <gensim.models.keyedvectors.Vocab at 0x7efc99a39810>,
#  'nt': <gensim.models.keyedvectors.Vocab at 0x7efc99a39850>,
#  'PP': <gensim.models.keyedvectors.Vocab at 0x7efc99a39890>,
#  'wT': <gensim.models.keyedvectors.Vocab at 0x7efc99a398d0>,
#  'observation': <gensim.models.keyedvectors.Vocab at 0x7efc99a39910>,
#  'kernel': <gensim.models.keyedvectors.Vocab at 0x7efc99a39950>,
#  'Ne': <gensim.models.keyedvectors.Vocab at 0x7efc99a39990>,
#  'KK': <gensim.models.keyedvectors.Vocab at 0x7efc99a399d0>,
#  'rc': <gensim.models.keyedvectors.Vocab at 0x7efc99a39a10>,
#  'oo': <gensim.models.keyedvectors.Vocab at 0x7efc99a39a50>,
#  'bh': <gensim.models.keyedvectors.Vocab at 0x7efc99a39a90>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x7efc99a39ad0>,
#  'ay': <gensim.models.keyedvectors.Vocab at 0x7efc99a39b10>,
#  'uo': <gensim.models.keyedvectors.Vocab at 0x7efc99a39b50>,
#  'av': <gensim.models.keyedvectors.Vocab at 0x7efc99a39b90>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x7efc99a39bd0>,
#  'jointly': <gensim.models.keyedvectors.Vocab at 0x7efc99a39c10>,
#  'Py': <gensim.models.keyedvectors.Vocab at 0x7efc99a39c50>,
#  'az': <gensim.models.keyedvectors.Vocab at 0x7efc99a39c90>,
#  'Several': <gensim.models.keyedvectors.Vocab at 0x7efc99a39cd0>,
#  'packages': <gensim.models.keyedvectors.Vocab at 0x7efc99a39d10>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x7efc99a39d50>,
#  'As': <gensim.models.keyedvectors.Vocab at 0x7efc99a39d90>,
#  'select': <gensim.models.keyedvectors.Vocab at 0x7efc99a39dd0>,
#  'straightforward': <gensim.models.keyedvectors.Vocab at 0x7efc99a39e10>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7efc99a39e50>,
#  'explained': <gensim.models.keyedvectors.Vocab at 0x7efc99a39e90>,
#  'NUMERICAL': <gensim.models.keyedvectors.Vocab at 0x7efc99a39ed0>,
#  'RESULTS': <gensim.models.keyedvectors.Vocab at 0x7efc99a39f10>,
#  'apply': <gensim.models.keyedvectors.Vocab at 0x7efc99a39f50>,
#  'methods': <gensim.models.keyedvectors.Vocab at 0x7efc99a39f90>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x7efc99a39fd0>,
#  'yy': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d050>,
#  'Kse': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d090>,
#  'hyperparameters': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d0d0>,
#  'input': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d110>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d150>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d190>,
#  'determines': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d1d0>,
#  'relevance': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d210>,
#  'dimension': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d250>,
#  'hyperparameter': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d290>,
#  'controls': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d2d0>,
#  'magnitude': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d310>,
#  'output': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d350>,
#  'Require': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d390>,
#  'Line': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d3d0>,
#  'Maximum': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d410>,
#  'Estimate': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d450>,
#  'repeat': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d490>,
#  'cw': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d4d0>,
#  'Update': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d510>,
#  'motivated': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d550>,
#  'ordinal': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d590>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d5d0>,
#  'squared': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d610>,
#  'Lemma': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d650>,
#  'analytical': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d690>,
#  'expressions': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d6d0>,
#  'kernels': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d710>,
#  'Ll': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d750>,
#  'MA': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d790>,
#  'Kronecker': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d7d0>,
#  'delta': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d810>,
#  'Static': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d850>,
#  'Cournot': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d890>,
#  'oligopoly': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d8d0>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d910>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d950>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d990>,
#  'quantity': <gensim.models.keyedvectors.Vocab at 0x7efc99a3d9d0>,
#  'qj': <gensim.models.keyedvectors.Vocab at 0x7efc99a3da10>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x7efc99a3da50>,
#  'dictated': <gensim.models.keyedvectors.Vocab at 0x7efc99a3da90>,
#  'produced': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dad0>,
#  'QO': <gensim.models.keyedvectors.Vocab at 0x7efc99a3db10>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x7efc99a3db50>,
#  'cj': <gensim.models.keyedvectors.Vocab at 0x7efc99a3db90>,
#  'q': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dbd0>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dc10>,
#  'Pi': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dc50>,
#  'uy': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dc90>,
#  'ci': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dcd0>,
#  'qi': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dd10>,
#  'dj': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dd50>,
#  'By': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dd90>,
#  'characterizes': <gensim.models.keyedvectors.Vocab at 0x7efc99a3ddd0>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x7efc99a3de10>,
#  'growth': <gensim.models.keyedvectors.Vocab at 0x7efc99a3de50>,
#  'models': <gensim.models.keyedvectors.Vocab at 0x7efc99a3de90>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x7efc99a3ded0>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7efc99a3df10>,
#  'increasing': <gensim.models.keyedvectors.Vocab at 0x7efc99a3df50>,
#  'monotone': <gensim.models.keyedvectors.Vocab at 0x7efc99a3df90>,
#  'adding': <gensim.models.keyedvectors.Vocab at 0x7efc99a3dfd0>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x7efc99a41050>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7efc99a41090>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x7efc99a410d0>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7efc99a41110>,
#  'profits': <gensim.models.keyedvectors.Vocab at 0x7efc99a41150>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7efc99a41190>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7efc99a411d0>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7efc99a41210>,
#  'sells': <gensim.models.keyedvectors.Vocab at 0x7efc99a41250>,
#  'profit': <gensim.models.keyedvectors.Vocab at 0x7efc99a41290>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7efc99a412d0>,
#  'Q': <gensim.models.keyedvectors.Vocab at 0x7efc99a41310>,
#  'restrict': <gensim.models.keyedvectors.Vocab at 0x7efc99a41350>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7efc99a41390>,
#  'Due': <gensim.models.keyedvectors.Vocab at 0x7efc99a413d0>,
#  'straight': <gensim.models.keyedvectors.Vocab at 0x7efc99a41410>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x7efc99a41450>,
#  'analytic': <gensim.models.keyedvectors.Vocab at 0x7efc99a41490>,
#  'cannot': <gensim.models.keyedvectors.Vocab at 0x7efc99a414d0>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7efc99a41510>,
#  'Game': <gensim.models.keyedvectors.Vocab at 0x7efc99a41550>,
#  'Formulation': <gensim.models.keyedvectors.Vocab at 0x7efc99a41590>,
#  'discretize': <gensim.models.keyedvectors.Vocab at 0x7efc99a415d0>,
#  'grid': <gensim.models.keyedvectors.Vocab at 0x7efc99a41610>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7efc99a41650>,
#  'terminated': <gensim.models.keyedvectors.Vocab at 0x7efc99a41690>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7efc99a416d0>,
#  'First': <gensim.models.keyedvectors.Vocab at 0x7efc99a41710>,
#  'compare': <gensim.models.keyedvectors.Vocab at 0x7efc99a41750>,
#  'GPGame': <gensim.models.keyedvectors.Vocab at 0x7efc99a41790>,
#  'filling': <gensim.models.keyedvectors.Vocab at 0x7efc99a417d0>,
#  'measurements': <gensim.models.keyedvectors.Vocab at 0x7efc99a41810>,
#  'suggested': <gensim.models.keyedvectors.Vocab at 0x7efc99a41850>,
#  'enable': <gensim.models.keyedvectors.Vocab at 0x7efc99a41890>,
#  'initialized': <gensim.models.keyedvectors.Vocab at 0x7efc99a418d0>,
#  'Table': <gensim.models.keyedvectors.Vocab at 0x7efc99a41910>,
#  'compares': <gensim.models.keyedvectors.Vocab at 0x7efc99a41950>,
#  'iterations': <gensim.models.keyedvectors.Vocab at 0x7efc99a41990>,
#  'required': <gensim.models.keyedvectors.Vocab at 0x7efc99a419d0>,
#  'Probability': <gensim.models.keyedvectors.Vocab at 0x7efc99a41a10>,
#  'Equilibrium': <gensim.models.keyedvectors.Vocab at 0x7efc99a41a50>,
#  'performs': <gensim.models.keyedvectors.Vocab at 0x7efc99a41a90>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7efc99a41ad0>,
#  'setup': <gensim.models.keyedvectors.Vocab at 0x7efc99a41b10>,
#  'utilizes': <gensim.models.keyedvectors.Vocab at 0x7efc99a41b50>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x7efc99a41b90>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x7efc99a41bd0>,
#  'quadrant': <gensim.models.keyedvectors.Vocab at 0x7efc99a41c10>,
#  'probabilities': <gensim.models.keyedvectors.Vocab at 0x7efc99a41c50>,
#  'multivariate': <gensim.models.keyedvectors.Vocab at 0x7efc99a41c90>,
#  'Gaussians': <gensim.models.keyedvectors.Vocab at 0x7efc99a41cd0>,
#  'weights': <gensim.models.keyedvectors.Vocab at 0x7efc99a41d10>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7efc99a41d50>,
#  'estimator': <gensim.models.keyedvectors.Vocab at 0x7efc99a41d90>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x7efc99a41dd0>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x7efc99a41e10>,
#  'differs': <gensim.models.keyedvectors.Vocab at 0x7efc99a41e50>,
#  'setting': <gensim.models.keyedvectors.Vocab at 0x7efc99a41e90>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x7efc99a41ed0>,
#  'fraction': <gensim.models.keyedvectors.Vocab at 0x7efc99a41f10>,
#  'fully': <gensim.models.keyedvectors.Vocab at 0x7efc99a41f50>,
#  'experiment': <gensim.models.keyedvectors.Vocab at 0x7efc99a41f90>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7efc99a41fd0>,
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x7efc99a44050>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7efc99a44090>,
#  'At': <gensim.models.keyedvectors.Vocab at 0x7efc99a440d0>,
#  'Iterations': <gensim.models.keyedvectors.Vocab at 0x7efc99a44110>,
#  'Exponential': <gensim.models.keyedvectors.Vocab at 0x7efc99a44150>,
#  'Comparison': <gensim.models.keyedvectors.Vocab at 0x7efc99a44190>,
#  'uses': <gensim.models.keyedvectors.Vocab at 0x7efc99a441d0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7efc99a44210>,
#  'Convergence': <gensim.models.keyedvectors.Vocab at 0x7efc99a44250>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x7efc99a44290>,
#  'superimposed': <gensim.models.keyedvectors.Vocab at 0x7efc99a442d0>,
#  'contour': <gensim.models.keyedvectors.Vocab at 0x7efc99a44310>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x7efc99a44350>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7efc99a44390>,
#  'optimal': <gensim.models.keyedvectors.Vocab at 0x7efc99a443d0>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x7efc99a44410>,
#  'inset': <gensim.models.keyedvectors.Vocab at 0x7efc99a44450>,
#  'initially': <gensim.models.keyedvectors.Vocab at 0x7efc99a44490>,
#  'selects': <gensim.models.keyedvectors.Vocab at 0x7efc99a444d0>,
#  'larger': <gensim.models.keyedvectors.Vocab at 0x7efc99a44510>,
#  'explores': <gensim.models.keyedvectors.Vocab at 0x7efc99a44550>,
#  'followed': <gensim.models.keyedvectors.Vocab at 0x7efc99a44590>,
#  'smaller': <gensim.models.keyedvectors.Vocab at 0x7efc99a445d0>,
#  'exploits': <gensim.models.keyedvectors.Vocab at 0x7efc99a44610>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x7efc99a44650>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x7efc99a44690>,
#  'optimum': <gensim.models.keyedvectors.Vocab at 0x7efc99a446d0>,
#  'Fig': <gensim.models.keyedvectors.Vocab at 0x7efc99a44710>,
#  'Also': <gensim.models.keyedvectors.Vocab at 0x7efc99a44750>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x7efc99a44790>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x7efc99a447d0>,
#  'extend': <gensim.models.keyedvectors.Vocab at 0x7efc99a44810>,
#  'ideas': <gensim.models.keyedvectors.Vocab at 0x7efc99a44850>,
#  'handle': <gensim.models.keyedvectors.Vocab at 0x7efc99a44890>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x7efc99a448d0>,
#  'optimizer': <gensim.models.keyedvectors.Vocab at 0x7efc99a44910>,
#  'BOBYQA': <gensim.models.keyedvectors.Vocab at 0x7efc99a44950>,
#  'quadratic': <gensim.models.keyedvectors.Vocab at 0x7efc99a44990>,
#  'approximation': <gensim.models.keyedvectors.Vocab at 0x7efc99a449d0>,
#  'averaged': <gensim.models.keyedvectors.Vocab at 0x7efc99a44a10>,
#  'independent': <gensim.models.keyedvectors.Vocab at 0x7efc99a44a50>,
#  'runs': <gensim.models.keyedvectors.Vocab at 0x7efc99a44a90>,
#  'varying': <gensim.models.keyedvectors.Vocab at 0x7efc99a44ad0>,
#  ...}

# %% [markdown]
# saves model as both .bin and .txt files

# %%
model.wv.save_word2vec_format('model'+ str(num_features) + '.bin', binary=True)
model.wv.save_word2vec_format('model'+ str(num_features) + '.txt', binary=False)
# Out:
# 2020-06-23 16:32:51,812 : INFO : storing 23740x100 projection weights into model100.bin
# 2020-06-23 16:32:51,954 : INFO : storing 23740x100 projection weights into model100.txt
